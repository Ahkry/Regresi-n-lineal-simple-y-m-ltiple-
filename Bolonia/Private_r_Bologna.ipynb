# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#cargar archivo desde seaborn 
df=pd.read_csv('Bologna_clean.csv')
#eliminamos la columna unnamed 
df= df.drop(['Unnamed: 0'], axis=1)
df.head(5)
# Out:
#                            listing_url  \
# 0   https://www.airbnb.com/rooms/42196
# 1   https://www.airbnb.com/rooms/46352
# 2   https://www.airbnb.com/rooms/85368
# 3  https://www.airbnb.com/rooms/204553
# 4  https://www.airbnb.com/rooms/219878
#
#                                                name  \
# 0               50 sm Studio in the historic centre
# 1                        A room in Pasolini's house
# 2                              Garden House Bologna
# 3  Private Room & Bath Ex-Convent in Centro Storico
# 4                  Gorgeous Haven in Centro Storico
#
#                                          description  \
# 0  The studio is a fully restored ancient basemen...
# 1  Simple, cozy and silent room in a lived house ...
# 2                      No se proporciona descripción
# 3  The neighbourhood is the most prestigious of B...
# 4  Quiet, bright, fully equipped 800 square feet ...
#
#                                neighborhood_overview  \
# 0                        No se proporcionan detalles
# 1  In the very nearby you have Via Saragozza and ...
# 2                        No se proporcionan detalles
# 3  Safest, most central, quietest street in Bolog...
# 4  has many shops, cafes, wine bars, restaurants ...
#
#                                          picture_url   host_name  host_since  \
# 0  https://a0.muscache.com/pictures/4775726/68044...       Carlo  2010-07-29
# 1  https://a0.muscache.com/pictures/9f94acc3-98fc...    Eleonora  2011-03-28
# 2  https://a0.muscache.com/pictures/585815/331d45...  Anna Maria  2011-03-28
# 3  https://a0.muscache.com/pictures/36151297/8be9...   Elizabeth  2011-05-09
# 4  https://a0.muscache.com/pictures/f16e5b7e-68b3...       Elisa  2011-09-10
#
#    host_response_time host_response_rate host_is_superhost  ...  \
# 0      within an hour               100%                 f  ...
# 1  a few days or more                44%                 f  ...
# 2         Desconocido                 -%                 f  ...
# 3      within an hour               100%                 f  ...
# 4  within a few hours               100%                 t  ...
#
#   review_scores_cleanliness review_scores_checkin review_scores_communication  \
# 0                      4.65                  4.92                        4.88
# 1                      4.60                  4.83                        4.85
# 2                      4.83                  4.98                        4.98
# 3                      4.92                  4.94                        4.93
# 4                      4.95                  4.90                        4.92
#
#   review_scores_location review_scores_value calculated_host_listings_count  \
# 0                   4.87                4.66                            2.0
# 1                   4.84                4.67                            2.0
# 2                   4.80                4.81                            1.0
# 3                   4.97                4.86                            1.0
# 4                   4.84                4.78                            2.0
#
#   calculated_host_listings_count_entire_homes  \
# 0                                         2.0
# 1                                         0.0
# 2                                         1.0
# 3                                         0.0
# 4                                         2.0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                          0.0
# 1                                          2.0
# 2                                          0.0
# 3                                          1.0
# 4                                          0.0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                         0.0              1.37
# 1                                         0.0              2.57
# 2                                         0.0              0.39
# 3                                         0.0              1.68
# 4                                         0.0              1.09
#
# [5 rows x 50 columns]

# %%
f1=df.iloc[ :  , [8,9,10,13,14,20,24,25,28,40] ]
f1
# Out:
#      host_response_rate host_is_superhost host_identity_verified  \
# 0                  100%                 f                      t
# 1                   44%                 f                      t
# 2                    -%                 f                      t
# 3                  100%                 f                      t
# 4                  100%                 t                      t
# ...                 ...               ...                    ...
# 4838               100%                 f                      f
# 4839               100%                 f                      t
# 4840                 -%                 f                      f
# 4841               100%                 f                      t
# 4842                 -%                 f                      t
#
#                     property_type        room_type instant_bookable  \
# 0              Entire rental unit  Entire home/apt                t
# 1     Private room in rental unit     Private room                f
# 2              Entire rental unit  Entire home/apt                f
# 3     Private room in rental unit     Private room                f
# 4              Entire rental unit  Entire home/apt                f
# ...                           ...              ...              ...
# 4838         Private room in home     Private room                f
# 4839           Entire rental unit  Entire home/apt                f
# 4840           Entire rental unit  Entire home/apt                t
# 4841           Entire rental unit  Entire home/apt                f
# 4842           Entire rental unit  Entire home/apt                t
#
#       accommodates  bathrooms  price  review_scores_cleanliness
# 0              2.0        1.0   80.0                       4.65
# 1              2.0        1.0   43.0                       4.60
# 2              5.0        1.0  120.0                       4.83
# 3              2.0        1.0   92.0                       4.92
# 4              2.0        1.0  147.0                       4.95
# ...            ...        ...    ...                        ...
# 4838           2.0        1.0   70.0                       5.00
# 4839           5.0        1.0  254.0                       5.00
# 4840           4.0        1.0   84.0                       5.00
# 4841           2.0        1.0  100.0                       5.00
# 4842           5.0        1.0  240.0                       5.00
#
# [4843 rows x 10 columns]

# %%
#convertimos string a tipos numéricos
f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})

#from sklearn.preprocessing import LabelEncoder
#encoder = LabelEncoder()
#f1['property_type'] = encoder.fit_transform(f1['property_type'])
#f1['property_type'] = f1['property_type'].astype(float)

frecuencias = f1['property_type'].value_counts()
f1['property_type'] = f1['property_type'].map(frecuencias)

f1['host_response_rate'] = f1['host_response_rate'].astype(str).str.rstrip('%')
f1['host_response_rate'] = pd.to_numeric(f1['host_response_rate'], errors='coerce').fillna(0)

f1['room_type'] = f1['room_type'].map({
    'Entire home/apt': 1,
    'Private room': 2,
    'Shared room': 3,
    'Hotel room': 4
})

f1['price'] = f1['price'].astype(str).str.rstrip('$')
f1['price'] = pd.to_numeric(f1['price'], errors='coerce').fillna(0)
# Out:
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_21292\844334906.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_21292\844334906.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_21292\844334906.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_21292\844334906.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_21292\844334906.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_21292\844334906.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_21292\844334906.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['property_type'] = f1['property_type'].map(frecuencias)
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_21292\844334906.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_response_rate'] = f1['host_response_rate'].astype(str).str.rstrip('%')
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_21292\844334906.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_response_rate'] = pd.to_numeric(f1['host_response_rate'], errors='coerce').fillna(0)
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_21292\844334906.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['room_type'] = f1['room_type'].map({
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_21292\844334906.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['price'] = f1['price'].astype(str).str.rstrip('$')
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_21292\844334906.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['price'] = pd.to_numeric(f1['price'], errors='coerce').fillna(0)

# %%
#f2 = Private room
f2= f1[(f1["room_type"] == 2)]

# %%
f2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1056 entries, 1 to 4838
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   host_response_rate         1056 non-null   float64
#  1   host_is_superhost          1056 non-null   int64
#  2   host_identity_verified     1056 non-null   int64
#  3   property_type              1056 non-null   int64
#  4   room_type                  1056 non-null   int64
#  5   instant_bookable           1056 non-null   int64
#  6   accommodates               1056 non-null   float64
#  7   bathrooms                  1056 non-null   float64
#  8   price                      1056 non-null   float64
#  9   review_scores_cleanliness  1056 non-null   float64
# dtypes: float64(5), int64(5)
# memory usage: 90.8 KB

# %%
#imprimimos el scatter plot entre la variable dependiente total e independiente (a)
#para observar el comportamiento en su dispersión 

from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='host_response_rate', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='host_is_superhost', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='host_identity_verified', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='property_type', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='room_type', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='instant_bookable', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='review_scores_cleanliness', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='accommodates', color='blue', data=f2)
sns.scatterplot(x='bathrooms', y='accommodates', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='accommodates'>

# %% [markdown]
# **DECLARACIÓN DE VARIABLES INDEPENDIENTES Y DEPENDIENTES**

# %%
#declaración de las variables independientes que se van a comparar con el precio 
Var_Indep= f2[['host_response_rate']]
Var_Indep2=f2[['host_is_superhost']]
Var_Indep3=f2[['room_type']]
Var_Indep4=f2[['host_identity_verified']]
Var_Indep5= f2[['property_type']]
Var_Indep6= f2[['instant_bookable']]
Var_Indep7= f2[['review_scores_cleanliness']]
#declaración de variable independiente para accommodates 
Var_Indep8= f2[['bathrooms']]

# %%
#variables independientes para la regresión lineal
Var_Dep= f2['price']
Var_Dep2= f2['accommodates']

# %% [markdown]
# **DEFINICIÓN DEL MODELO**

# %%
#se define model como función de regresión lineal 
from sklearn.linear_model import LinearRegression 
model=LinearRegression()
model2=LinearRegression()
model3=LinearRegression()
model4=LinearRegression()
model5=LinearRegression()
model6=LinearRegression()
model7=LinearRegression()
model8=LinearRegression()

# %%
#verficamos la función relacionada al modelo 
type(model)
type(model2)
type(model3)
type(model4)
type(model5)
type(model6)
type(model7)
type(model8)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#ajustamos el modelo con las variables antes declaradas
model.fit(X=Var_Indep, y=Var_Dep)
model2.fit(X=Var_Indep2, y=Var_Dep)
model3.fit(X=Var_Indep3, y=Var_Dep)
model4.fit(X=Var_Indep4, y=Var_Dep)
model5.fit(X=Var_Indep5, y=Var_Dep)
model6.fit(X=Var_Indep6, y=Var_Dep)
model7.fit(X=Var_Indep7, y=Var_Dep)
model8.fit(X=Var_Indep8, y=Var_Dep2)
# Out:
# LinearRegression()

# %% [markdown]
# **COEFICIENTES OBTENIDOS PARA NUESTROS MODELOS**

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-0.21119011]),
#  'rank_': 1,
#  'singular_': array([1202.4214143]),
#  'intercept_': np.float64(127.5510054865531)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model2.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_is_superhost'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-12.44023271]),
#  'rank_': 1,
#  'singular_': array([15.57861296]),
#  'intercept_': np.float64(114.99764011799412)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model3.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['room_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.]),
#  'rank_': 0,
#  'singular_': array([0.]),
#  'intercept_': np.float64(110.54460227272727)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model4.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_identity_verified'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([7.19894813]),
#  'rank_': 1,
#  'singular_': array([8.0845438]),
#  'intercept_': np.float64(103.82285714285713)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model5.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['property_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-0.0532293]),
#  'rank_': 1,
#  'singular_': array([4789.98173235]),
#  'intercept_': np.float64(125.5751238963788)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model6.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['instant_bookable'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([38.01025253]),
#  'rank_': 1,
#  'singular_': array([15.73213272]),
#  'intercept_': np.float64(96.29075757575757)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model7.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([54.12400325]),
#  'rank_': 1,
#  'singular_': array([5.33097786]),
#  'intercept_': np.float64(-152.8696435041888)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model8.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['bathrooms'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.]),
#  'rank_': 0,
#  'singular_': array([0.]),
#  'intercept_': np.float64(2.1602272727272727)}

# %% [markdown]
# **A PARTIR DE AQUÍ PREDECIMOS VALORES DE ACUERDO AL MODELO MATEMÁTICO**

# %% [markdown]
# **Modelo matemático y=-0.94114872x + 1327.7330443080114**

# %%
#predecimos valores
y_pred= model.predict(X=f2[['host_response_rate']])
y_pred
# Out:
# array([118.25864085, 106.43199496, 106.43199496, ..., 106.43199496,
#        116.99150022, 106.43199496], shape=(1056,))

# %% [markdown]
# **Modelo matemático y=21.00986237x + 1237.7516553524084**

# %%
#predecimos valores
y_pred2= model2.predict(X=f2[['host_is_superhost']])
y_pred2
# Out:
# array([114.99764012, 114.99764012, 114.99764012, ..., 114.99764012,
#        114.99764012, 114.99764012], shape=(1056,))

# %% [markdown]
# **Modelo matemático y=0x + 11247.1754189944133**

# %%
#predecimos valores
y_pred3= model3.predict(X=f2[['room_type']])
y_pred3
# Out:
# array([110.54460227, 110.54460227, 110.54460227, ..., 110.54460227,
#        110.54460227, 110.54460227], shape=(1056,))

# %% [markdown]
# **Modelo matemático y=-112.80942578x + 1357.171593533486**

# %%
#predecimos valores
y_pred4= model4.predict(X=f2[['host_identity_verified']])
y_pred4
# Out:
# array([111.02180527, 111.02180527, 111.02180527, ..., 111.02180527,
#        111.02180527, 103.82285714], shape=(1056,))

# %% [markdown]
# **Modelo matemático y=-4.56100445x + 1325.0492572068565**

# %%
#predecimos valores
y_pred5= model5.predict(X=f2[['property_type']])
y_pred5
# Out:
# array([102.47360947, 102.47360947, 111.30967259, ..., 102.47360947,
#        102.47360947, 123.33949347], shape=(1056,))

# %% [markdown]
# **Modelo matemático y=71.48464608x + 1217.0755372065255**

# %%
#predecimos valores
y_pred6= model6.predict(X=f2[['instant_bookable']])
y_pred6
# Out:
# array([96.29075758, 96.29075758, 96.29075758, ..., 96.29075758,
#        96.29075758, 96.29075758], shape=(1056,))

# %% [markdown]
# **Modelo matemático y=381.28956491x + -604.4218714343112**

# %%
y_pred7= model7.predict(X=f2[['review_scores_cleanliness']])
y_pred7
# Out:
# array([ 96.10077144, 113.42045248, 115.58541261, ..., 117.75037274,
#        117.75037274, 117.75037274], shape=(1056,))

# %% [markdown]
# **Modelo matemático y=0.97488088x + 2.1063441944025767**

# %%
y_pred8= model8.predict(X=f2[['bathrooms']])
y_pred8
# Out:
# array([2.16022727, 2.16022727, 2.16022727, ..., 2.16022727, 2.16022727,
#        2.16022727], shape=(1056,))

# %% [markdown]
# **INSERTAMOS LA COLUMNA DE PREDICCIONES A NUESTRO DATAFRAME**

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(0, 'Prediccion_host_response_rate', y_pred)
f2
# Out:
#       Prediccion_host_response_rate  host_response_rate  host_is_superhost  \
# 1                        118.258641                44.0                  0
# 3                        106.431995               100.0                  0
# 6                        106.431995               100.0                  0
# 9                        106.431995               100.0                  0
# 13                       106.431995               100.0                  0
# ...                             ...                 ...                ...
# 4825                     106.431995               100.0                  0
# 4827                     106.431995               100.0                  0
# 4828                     106.431995               100.0                  0
# 4834                     116.991500                50.0                  0
# 4838                     106.431995               100.0                  0
#
#       host_identity_verified  property_type  room_type  instant_bookable  \
# 1                          1            434          2                 0
# 3                          1            434          2                 0
# 6                          1            268          2                 0
# 9                          1            434          2                 0
# 13                         1            181          2                 0
# ...                      ...            ...        ...               ...
# 4825                       1            434          2                 0
# 4827                       1            434          2                 0
# 4828                       1            434          2                 0
# 4834                       1            434          2                 0
# 4838                       0             42          2                 0
#
#       accommodates  bathrooms  price  review_scores_cleanliness
# 1              2.0        1.0   43.0                       4.60
# 3              2.0        1.0   92.0                       4.92
# 6              2.0        1.0  100.0                       4.96
# 9              2.0        1.0  159.0                       4.88
# 13             2.0        1.0   80.0                       4.45
# ...            ...        ...    ...                        ...
# 4825           1.0        1.0   48.0                       5.00
# 4827           2.0        1.0   80.0                       5.00
# 4828           2.0        1.0   56.0                       5.00
# 4834           1.0        1.0   75.0                       5.00
# 4838           2.0        1.0   70.0                       5.00
#
# [1056 rows x 11 columns]

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(1, 'Prediccion_host_is_superhost', y_pred2)
f2
# Out:
#       Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 1                        118.258641                     114.99764
# 3                        106.431995                     114.99764
# 6                        106.431995                     114.99764
# 9                        106.431995                     114.99764
# 13                       106.431995                     114.99764
# ...                             ...                           ...
# 4825                     106.431995                     114.99764
# 4827                     106.431995                     114.99764
# 4828                     106.431995                     114.99764
# 4834                     116.991500                     114.99764
# 4838                     106.431995                     114.99764
#
#       host_response_rate  host_is_superhost  host_identity_verified  \
# 1                   44.0                  0                       1
# 3                  100.0                  0                       1
# 6                  100.0                  0                       1
# 9                  100.0                  0                       1
# 13                 100.0                  0                       1
# ...                  ...                ...                     ...
# 4825               100.0                  0                       1
# 4827               100.0                  0                       1
# 4828               100.0                  0                       1
# 4834                50.0                  0                       1
# 4838               100.0                  0                       0
#
#       property_type  room_type  instant_bookable  accommodates  bathrooms  \
# 1               434          2                 0           2.0        1.0
# 3               434          2                 0           2.0        1.0
# 6               268          2                 0           2.0        1.0
# 9               434          2                 0           2.0        1.0
# 13              181          2                 0           2.0        1.0
# ...             ...        ...               ...           ...        ...
# 4825            434          2                 0           1.0        1.0
# 4827            434          2                 0           2.0        1.0
# 4828            434          2                 0           2.0        1.0
# 4834            434          2                 0           1.0        1.0
# 4838             42          2                 0           2.0        1.0
#
#       price  review_scores_cleanliness
# 1      43.0                       4.60
# 3      92.0                       4.92
# 6     100.0                       4.96
# 9     159.0                       4.88
# 13     80.0                       4.45
# ...     ...                        ...
# 4825   48.0                       5.00
# 4827   80.0                       5.00
# 4828   56.0                       5.00
# 4834   75.0                       5.00
# 4838   70.0                       5.00
#
# [1056 rows x 12 columns]

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(2, 'Prediccion_room_type', y_pred3)
f2
# Out:
#       Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 1                        118.258641                     114.99764
# 3                        106.431995                     114.99764
# 6                        106.431995                     114.99764
# 9                        106.431995                     114.99764
# 13                       106.431995                     114.99764
# ...                             ...                           ...
# 4825                     106.431995                     114.99764
# 4827                     106.431995                     114.99764
# 4828                     106.431995                     114.99764
# 4834                     116.991500                     114.99764
# 4838                     106.431995                     114.99764
#
#       Prediccion_room_type  host_response_rate  host_is_superhost  \
# 1               110.544602                44.0                  0
# 3               110.544602               100.0                  0
# 6               110.544602               100.0                  0
# 9               110.544602               100.0                  0
# 13              110.544602               100.0                  0
# ...                    ...                 ...                ...
# 4825            110.544602               100.0                  0
# 4827            110.544602               100.0                  0
# 4828            110.544602               100.0                  0
# 4834            110.544602                50.0                  0
# 4838            110.544602               100.0                  0
#
#       host_identity_verified  property_type  room_type  instant_bookable  \
# 1                          1            434          2                 0
# 3                          1            434          2                 0
# 6                          1            268          2                 0
# 9                          1            434          2                 0
# 13                         1            181          2                 0
# ...                      ...            ...        ...               ...
# 4825                       1            434          2                 0
# 4827                       1            434          2                 0
# 4828                       1            434          2                 0
# 4834                       1            434          2                 0
# 4838                       0             42          2                 0
#
#       accommodates  bathrooms  price  review_scores_cleanliness
# 1              2.0        1.0   43.0                       4.60
# 3              2.0        1.0   92.0                       4.92
# 6              2.0        1.0  100.0                       4.96
# 9              2.0        1.0  159.0                       4.88
# 13             2.0        1.0   80.0                       4.45
# ...            ...        ...    ...                        ...
# 4825           1.0        1.0   48.0                       5.00
# 4827           2.0        1.0   80.0                       5.00
# 4828           2.0        1.0   56.0                       5.00
# 4834           1.0        1.0   75.0                       5.00
# 4838           2.0        1.0   70.0                       5.00
#
# [1056 rows x 13 columns]

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(3, 'Prediccion_host_identity_verified', y_pred4)
f2
# Out:
#       Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 1                        118.258641                     114.99764
# 3                        106.431995                     114.99764
# 6                        106.431995                     114.99764
# 9                        106.431995                     114.99764
# 13                       106.431995                     114.99764
# ...                             ...                           ...
# 4825                     106.431995                     114.99764
# 4827                     106.431995                     114.99764
# 4828                     106.431995                     114.99764
# 4834                     116.991500                     114.99764
# 4838                     106.431995                     114.99764
#
#       Prediccion_room_type  Prediccion_host_identity_verified  \
# 1               110.544602                         111.021805
# 3               110.544602                         111.021805
# 6               110.544602                         111.021805
# 9               110.544602                         111.021805
# 13              110.544602                         111.021805
# ...                    ...                                ...
# 4825            110.544602                         111.021805
# 4827            110.544602                         111.021805
# 4828            110.544602                         111.021805
# 4834            110.544602                         111.021805
# 4838            110.544602                         103.822857
#
#       host_response_rate  host_is_superhost  host_identity_verified  \
# 1                   44.0                  0                       1
# 3                  100.0                  0                       1
# 6                  100.0                  0                       1
# 9                  100.0                  0                       1
# 13                 100.0                  0                       1
# ...                  ...                ...                     ...
# 4825               100.0                  0                       1
# 4827               100.0                  0                       1
# 4828               100.0                  0                       1
# 4834                50.0                  0                       1
# 4838               100.0                  0                       0
#
#       property_type  room_type  instant_bookable  accommodates  bathrooms  \
# 1               434          2                 0           2.0        1.0
# 3               434          2                 0           2.0        1.0
# 6               268          2                 0           2.0        1.0
# 9               434          2                 0           2.0        1.0
# 13              181          2                 0           2.0        1.0
# ...             ...        ...               ...           ...        ...
# 4825            434          2                 0           1.0        1.0
# 4827            434          2                 0           2.0        1.0
# 4828            434          2                 0           2.0        1.0
# 4834            434          2                 0           1.0        1.0
# 4838             42          2                 0           2.0        1.0
#
#       price  review_scores_cleanliness
# 1      43.0                       4.60
# 3      92.0                       4.92
# 6     100.0                       4.96
# 9     159.0                       4.88
# 13     80.0                       4.45
# ...     ...                        ...
# 4825   48.0                       5.00
# 4827   80.0                       5.00
# 4828   56.0                       5.00
# 4834   75.0                       5.00
# 4838   70.0                       5.00
#
# [1056 rows x 14 columns]

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(4, 'Prediccion_property_type', y_pred5)
f2
# Out:
#       Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 1                        118.258641                     114.99764
# 3                        106.431995                     114.99764
# 6                        106.431995                     114.99764
# 9                        106.431995                     114.99764
# 13                       106.431995                     114.99764
# ...                             ...                           ...
# 4825                     106.431995                     114.99764
# 4827                     106.431995                     114.99764
# 4828                     106.431995                     114.99764
# 4834                     116.991500                     114.99764
# 4838                     106.431995                     114.99764
#
#       Prediccion_room_type  Prediccion_host_identity_verified  \
# 1               110.544602                         111.021805
# 3               110.544602                         111.021805
# 6               110.544602                         111.021805
# 9               110.544602                         111.021805
# 13              110.544602                         111.021805
# ...                    ...                                ...
# 4825            110.544602                         111.021805
# 4827            110.544602                         111.021805
# 4828            110.544602                         111.021805
# 4834            110.544602                         111.021805
# 4838            110.544602                         103.822857
#
#       Prediccion_property_type  host_response_rate  host_is_superhost  \
# 1                   102.473609                44.0                  0
# 3                   102.473609               100.0                  0
# 6                   111.309673               100.0                  0
# 9                   102.473609               100.0                  0
# 13                  115.940621               100.0                  0
# ...                        ...                 ...                ...
# 4825                102.473609               100.0                  0
# 4827                102.473609               100.0                  0
# 4828                102.473609               100.0                  0
# 4834                102.473609                50.0                  0
# 4838                123.339493               100.0                  0
#
#       host_identity_verified  property_type  room_type  instant_bookable  \
# 1                          1            434          2                 0
# 3                          1            434          2                 0
# 6                          1            268          2                 0
# 9                          1            434          2                 0
# 13                         1            181          2                 0
# ...                      ...            ...        ...               ...
# 4825                       1            434          2                 0
# 4827                       1            434          2                 0
# 4828                       1            434          2                 0
# 4834                       1            434          2                 0
# 4838                       0             42          2                 0
#
#       accommodates  bathrooms  price  review_scores_cleanliness
# 1              2.0        1.0   43.0                       4.60
# 3              2.0        1.0   92.0                       4.92
# 6              2.0        1.0  100.0                       4.96
# 9              2.0        1.0  159.0                       4.88
# 13             2.0        1.0   80.0                       4.45
# ...            ...        ...    ...                        ...
# 4825           1.0        1.0   48.0                       5.00
# 4827           2.0        1.0   80.0                       5.00
# 4828           2.0        1.0   56.0                       5.00
# 4834           1.0        1.0   75.0                       5.00
# 4838           2.0        1.0   70.0                       5.00
#
# [1056 rows x 15 columns]

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(5, 'Prediccion_instant_bookable', y_pred6)
f2
# Out:
#       Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 1                        118.258641                     114.99764
# 3                        106.431995                     114.99764
# 6                        106.431995                     114.99764
# 9                        106.431995                     114.99764
# 13                       106.431995                     114.99764
# ...                             ...                           ...
# 4825                     106.431995                     114.99764
# 4827                     106.431995                     114.99764
# 4828                     106.431995                     114.99764
# 4834                     116.991500                     114.99764
# 4838                     106.431995                     114.99764
#
#       Prediccion_room_type  Prediccion_host_identity_verified  \
# 1               110.544602                         111.021805
# 3               110.544602                         111.021805
# 6               110.544602                         111.021805
# 9               110.544602                         111.021805
# 13              110.544602                         111.021805
# ...                    ...                                ...
# 4825            110.544602                         111.021805
# 4827            110.544602                         111.021805
# 4828            110.544602                         111.021805
# 4834            110.544602                         111.021805
# 4838            110.544602                         103.822857
#
#       Prediccion_property_type  Prediccion_instant_bookable  \
# 1                   102.473609                    96.290758
# 3                   102.473609                    96.290758
# 6                   111.309673                    96.290758
# 9                   102.473609                    96.290758
# 13                  115.940621                    96.290758
# ...                        ...                          ...
# 4825                102.473609                    96.290758
# 4827                102.473609                    96.290758
# 4828                102.473609                    96.290758
# 4834                102.473609                    96.290758
# 4838                123.339493                    96.290758
#
#       host_response_rate  host_is_superhost  host_identity_verified  \
# 1                   44.0                  0                       1
# 3                  100.0                  0                       1
# 6                  100.0                  0                       1
# 9                  100.0                  0                       1
# 13                 100.0                  0                       1
# ...                  ...                ...                     ...
# 4825               100.0                  0                       1
# 4827               100.0                  0                       1
# 4828               100.0                  0                       1
# 4834                50.0                  0                       1
# 4838               100.0                  0                       0
#
#       property_type  room_type  instant_bookable  accommodates  bathrooms  \
# 1               434          2                 0           2.0        1.0
# 3               434          2                 0           2.0        1.0
# 6               268          2                 0           2.0        1.0
# 9               434          2                 0           2.0        1.0
# 13              181          2                 0           2.0        1.0
# ...             ...        ...               ...           ...        ...
# 4825            434          2                 0           1.0        1.0
# 4827            434          2                 0           2.0        1.0
# 4828            434          2                 0           2.0        1.0
# 4834            434          2                 0           1.0        1.0
# 4838             42          2                 0           2.0        1.0
#
#       price  review_scores_cleanliness
# 1      43.0                       4.60
# 3      92.0                       4.92
# 6     100.0                       4.96
# 9     159.0                       4.88
# 13     80.0                       4.45
# ...     ...                        ...
# 4825   48.0                       5.00
# 4827   80.0                       5.00
# 4828   56.0                       5.00
# 4834   75.0                       5.00
# 4838   70.0                       5.00
#
# [1056 rows x 16 columns]

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(6, 'Prediccion_review_scores_cleanliness', y_pred7)
f2
# Out:
#       Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 1                        118.258641                     114.99764
# 3                        106.431995                     114.99764
# 6                        106.431995                     114.99764
# 9                        106.431995                     114.99764
# 13                       106.431995                     114.99764
# ...                             ...                           ...
# 4825                     106.431995                     114.99764
# 4827                     106.431995                     114.99764
# 4828                     106.431995                     114.99764
# 4834                     116.991500                     114.99764
# 4838                     106.431995                     114.99764
#
#       Prediccion_room_type  Prediccion_host_identity_verified  \
# 1               110.544602                         111.021805
# 3               110.544602                         111.021805
# 6               110.544602                         111.021805
# 9               110.544602                         111.021805
# 13              110.544602                         111.021805
# ...                    ...                                ...
# 4825            110.544602                         111.021805
# 4827            110.544602                         111.021805
# 4828            110.544602                         111.021805
# 4834            110.544602                         111.021805
# 4838            110.544602                         103.822857
#
#       Prediccion_property_type  Prediccion_instant_bookable  \
# 1                   102.473609                    96.290758
# 3                   102.473609                    96.290758
# 6                   111.309673                    96.290758
# 9                   102.473609                    96.290758
# 13                  115.940621                    96.290758
# ...                        ...                          ...
# 4825                102.473609                    96.290758
# 4827                102.473609                    96.290758
# 4828                102.473609                    96.290758
# 4834                102.473609                    96.290758
# 4838                123.339493                    96.290758
#
#       Prediccion_review_scores_cleanliness  host_response_rate  \
# 1                                96.100771                44.0
# 3                               113.420452               100.0
# 6                               115.585413               100.0
# 9                               111.255492               100.0
# 13                               87.982171               100.0
# ...                                    ...                 ...
# 4825                            117.750373               100.0
# 4827                            117.750373               100.0
# 4828                            117.750373               100.0
# 4834                            117.750373                50.0
# 4838                            117.750373               100.0
#
#       host_is_superhost  host_identity_verified  property_type  room_type  \
# 1                     0                       1            434          2
# 3                     0                       1            434          2
# 6                     0                       1            268          2
# 9                     0                       1            434          2
# 13                    0                       1            181          2
# ...                 ...                     ...            ...        ...
# 4825                  0                       1            434          2
# 4827                  0                       1            434          2
# 4828                  0                       1            434          2
# 4834                  0                       1            434          2
# 4838                  0                       0             42          2
#
#       instant_bookable  accommodates  bathrooms  price  \
# 1                    0           2.0        1.0   43.0
# 3                    0           2.0        1.0   92.0
# 6                    0           2.0        1.0  100.0
# 9                    0           2.0        1.0  159.0
# 13                   0           2.0        1.0   80.0
# ...                ...           ...        ...    ...
# 4825                 0           1.0        1.0   48.0
# 4827                 0           2.0        1.0   80.0
# 4828                 0           2.0        1.0   56.0
# 4834                 0           1.0        1.0   75.0
# 4838                 0           2.0        1.0   70.0
#
#       review_scores_cleanliness
# 1                          4.60
# 3                          4.92
# 6                          4.96
# 9                          4.88
# 13                         4.45
# ...                         ...
# 4825                       5.00
# 4827                       5.00
# 4828                       5.00
# 4834                       5.00
# 4838                       5.00
#
# [1056 rows x 17 columns]

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(7, 'Prediccion_bathrooms', y_pred8)
f2
# Out:
#       Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 1                        118.258641                     114.99764
# 3                        106.431995                     114.99764
# 6                        106.431995                     114.99764
# 9                        106.431995                     114.99764
# 13                       106.431995                     114.99764
# ...                             ...                           ...
# 4825                     106.431995                     114.99764
# 4827                     106.431995                     114.99764
# 4828                     106.431995                     114.99764
# 4834                     116.991500                     114.99764
# 4838                     106.431995                     114.99764
#
#       Prediccion_room_type  Prediccion_host_identity_verified  \
# 1               110.544602                         111.021805
# 3               110.544602                         111.021805
# 6               110.544602                         111.021805
# 9               110.544602                         111.021805
# 13              110.544602                         111.021805
# ...                    ...                                ...
# 4825            110.544602                         111.021805
# 4827            110.544602                         111.021805
# 4828            110.544602                         111.021805
# 4834            110.544602                         111.021805
# 4838            110.544602                         103.822857
#
#       Prediccion_property_type  Prediccion_instant_bookable  \
# 1                   102.473609                    96.290758
# 3                   102.473609                    96.290758
# 6                   111.309673                    96.290758
# 9                   102.473609                    96.290758
# 13                  115.940621                    96.290758
# ...                        ...                          ...
# 4825                102.473609                    96.290758
# 4827                102.473609                    96.290758
# 4828                102.473609                    96.290758
# 4834                102.473609                    96.290758
# 4838                123.339493                    96.290758
#
#       Prediccion_review_scores_cleanliness  Prediccion_bathrooms  \
# 1                                96.100771              2.160227
# 3                               113.420452              2.160227
# 6                               115.585413              2.160227
# 9                               111.255492              2.160227
# 13                               87.982171              2.160227
# ...                                    ...                   ...
# 4825                            117.750373              2.160227
# 4827                            117.750373              2.160227
# 4828                            117.750373              2.160227
# 4834                            117.750373              2.160227
# 4838                            117.750373              2.160227
#
#       host_response_rate  host_is_superhost  host_identity_verified  \
# 1                   44.0                  0                       1
# 3                  100.0                  0                       1
# 6                  100.0                  0                       1
# 9                  100.0                  0                       1
# 13                 100.0                  0                       1
# ...                  ...                ...                     ...
# 4825               100.0                  0                       1
# 4827               100.0                  0                       1
# 4828               100.0                  0                       1
# 4834                50.0                  0                       1
# 4838               100.0                  0                       0
#
#       property_type  room_type  instant_bookable  accommodates  bathrooms  \
# 1               434          2                 0           2.0        1.0
# 3               434          2                 0           2.0        1.0
# 6               268          2                 0           2.0        1.0
# 9               434          2                 0           2.0        1.0
# 13              181          2                 0           2.0        1.0
# ...             ...        ...               ...           ...        ...
# 4825            434          2                 0           1.0        1.0
# 4827            434          2                 0           2.0        1.0
# 4828            434          2                 0           2.0        1.0
# 4834            434          2                 0           1.0        1.0
# 4838             42          2                 0           2.0        1.0
#
#       price  review_scores_cleanliness
# 1      43.0                       4.60
# 3      92.0                       4.92
# 6     100.0                       4.96
# 9     159.0                       4.88
# 13     80.0                       4.45
# ...     ...                        ...
# 4825   48.0                       5.00
# 4827   80.0                       5.00
# 4828   56.0                       5.00
# 4834   75.0                       5.00
# 4838   70.0                       5.00
#
# [1056 rows x 18 columns]

# %% [markdown]
# **GRÁFICAS COMPARATIVAS**

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='host_response_rate', y='price', color='blue', data=f2)
sns.scatterplot(x='host_response_rate', y='Prediccion_host_response_rate', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='host_is_superhost', y='price', color='blue', data=f2)
sns.scatterplot(x='host_is_superhost', y='Prediccion_host_is_superhost', color='red', data=f2)
#sns.lineplot(x='host_is_superhost', y='Predicciones2', color='red', data=f2)
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='room_type', y='Prediccion_room_type', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='host_identity_verified', y='price', color='blue', data=f2)
sns.scatterplot(x='host_identity_verified', y='Prediccion_host_identity_verified', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='host_identity_verified', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='property_type', y='price', color='blue', data=f2)
sns.scatterplot(x='property_type', y='Prediccion_property_type', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='instant_bookable', y='price', color='blue', data=f2)
sns.scatterplot(x='instant_bookable', y='Prediccion_instant_bookable', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='instant_bookable', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='review_scores_cleanliness', y='price', color='blue', data=f2)
sns.scatterplot(x='review_scores_cleanliness', y='Prediccion_review_scores_cleanliness', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='bathrooms', y='accommodates', color='blue', data=f2)
sns.scatterplot(x='bathrooms', y='Prediccion_bathrooms', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='bathrooms', ylabel='accommodates'>

# %% [markdown]
# **COEFICIENTES DE DETERMINACIÓN**

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter= model.score(X=Var_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.01743400045091814

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter2= model2.score(X=Var_Indep2, y=Var_Dep)
coef_Deter2
# Out:
# 0.010154325941569842

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter3= model3.score(X=Var_Indep3, y=Var_Dep)
coef_Deter3
# Out:
# 0.0

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter4= model4.score(X=Var_Indep4, y=Var_Dep)
coef_Deter4
# Out:
# 0.0009157683733841404

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter5= model5.score(X=Var_Indep5, y=Var_Dep)
coef_Deter5
# Out:
# 0.01757541840984811

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter6= model6.score(X=Var_Indep6, y=Var_Dep)
coef_Deter6
# Out:
# 0.09667478796932716

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter7= model7.score(X=Var_Indep7, y=Var_Dep)
coef_Deter7
# Out:
# 0.022507646997843356

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter8= model8.score(X=Var_Indep8, y=Var_Dep2)
coef_Deter8
# Out:
# 0.0

# %% [markdown]
# **COEFICIENTES DE CORRELACIÓN**

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.13203787506211292)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl2=np.sqrt(coef_Deter2)
coef_Correl2
# Out:
# np.float64(0.10076867539850785)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl3=np.sqrt(coef_Deter2)
coef_Correl3
# Out:
# np.float64(0.10076867539850785)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl4=np.sqrt(coef_Deter4)
coef_Correl4
# Out:
# np.float64(0.030261665079505132)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl5=np.sqrt(coef_Deter5)
coef_Correl5
# Out:
# np.float64(0.13257231388886637)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl6=np.sqrt(coef_Deter6)
coef_Correl6
# Out:
# np.float64(0.31092569525423136)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl7=np.sqrt(coef_Deter7)
coef_Correl7
# Out:
# np.float64(0.15002548782738004)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl8=np.sqrt(coef_Deter8)
coef_Correl8
# Out:
# np.float64(0.0)

# %%
#eliminamos room_type y su prediccion 

f2= f2.drop(['room_type', 'Prediccion_room_type' ], axis=1)

# %%
#Graficamos todas las dispersiones entre todas las variables
sns.pairplot(f2)

# %%
#Analizar categorias de una columna
df6 = f2.groupby(['host_response_rate'])['host_response_rate'].count()
df6
# Out:
# host_response_rate
# 0.0      168
# 10.0       1
# 13.0       2
# 15.0       2
# 25.0       3
# 33.0       2
# 35.0       1
# 38.0       1
# 40.0       2
# 42.0       2
# 43.0       2
# 44.0       3
# 50.0       9
# 56.0       1
# 57.0       2
# 60.0       2
# 63.0       3
# 64.0       1
# 67.0       8
# 70.0       3
# 71.0       2
# 75.0       1
# 78.0       6
# 80.0      12
# 83.0       1
# 85.0       2
# 87.0       1
# 88.0       7
# 89.0       4
# 90.0      24
# 91.0       6
# 92.0      11
# 93.0       4
# 94.0       8
# 95.0       1
# 96.0       3
# 97.0      10
# 98.0       6
# 99.0       5
# 100.0    724
# Name: host_response_rate, dtype: int64

# %%
#Encontramos todas las correlaciones entre las variables 
Corr_Factors= f2.corr()
Corr_Factors
# Out:
#                                       Prediccion_host_response_rate  \
# Prediccion_host_response_rate                              1.000000
# Prediccion_host_is_superhost                               0.332690
# Prediccion_host_identity_verified                         -0.191014
# Prediccion_property_type                                  -0.040113
# Prediccion_instant_bookable                               -0.105383
# Prediccion_review_scores_cleanliness                       0.107242
# Prediccion_bathrooms                                            NaN
# host_response_rate                                        -1.000000
# host_is_superhost                                         -0.332690
# host_identity_verified                                    -0.191014
# property_type                                              0.040113
# instant_bookable                                          -0.105383
# accommodates                                              -0.045568
# bathrooms                                                       NaN
# price                                                      0.132038
# review_scores_cleanliness                                  0.107242
#
#                                       Prediccion_host_is_superhost  \
# Prediccion_host_response_rate                             0.332690
# Prediccion_host_is_superhost                              1.000000
# Prediccion_host_identity_verified                        -0.079850
# Prediccion_property_type                                 -0.097426
# Prediccion_instant_bookable                              -0.029582
# Prediccion_review_scores_cleanliness                     -0.089403
# Prediccion_bathrooms                                           NaN
# host_response_rate                                       -0.332690
# host_is_superhost                                        -1.000000
# host_identity_verified                                   -0.079850
# property_type                                             0.097426
# instant_bookable                                         -0.029582
# accommodates                                             -0.020784
# bathrooms                                                      NaN
# price                                                     0.100769
# review_scores_cleanliness                                -0.089403
#
#                                       Prediccion_host_identity_verified  \
# Prediccion_host_response_rate                                 -0.191014
# Prediccion_host_is_superhost                                  -0.079850
# Prediccion_host_identity_verified                              1.000000
# Prediccion_property_type                                       0.036563
# Prediccion_instant_bookable                                    0.072727
# Prediccion_review_scores_cleanliness                          -0.100454
# Prediccion_bathrooms                                                NaN
# host_response_rate                                             0.191014
# host_is_superhost                                              0.079850
# host_identity_verified                                         1.000000
# property_type                                                 -0.036563
# instant_bookable                                               0.072727
# accommodates                                                   0.023917
# bathrooms                                                           NaN
# price                                                          0.030262
# review_scores_cleanliness                                     -0.100454
#
#                                       Prediccion_property_type  \
# Prediccion_host_response_rate                        -0.040113
# Prediccion_host_is_superhost                         -0.097426
# Prediccion_host_identity_verified                     0.036563
# Prediccion_property_type                              1.000000
# Prediccion_instant_bookable                           0.140648
# Prediccion_review_scores_cleanliness                  0.013122
# Prediccion_bathrooms                                       NaN
# host_response_rate                                    0.040113
# host_is_superhost                                     0.097426
# host_identity_verified                                0.036563
# property_type                                        -1.000000
# instant_bookable                                      0.140648
# accommodates                                          0.067881
# bathrooms                                                  NaN
# price                                                 0.132572
# review_scores_cleanliness                             0.013122
#
#                                       Prediccion_instant_bookable  \
# Prediccion_host_response_rate                           -0.105383
# Prediccion_host_is_superhost                            -0.029582
# Prediccion_host_identity_verified                        0.072727
# Prediccion_property_type                                 0.140648
# Prediccion_instant_bookable                              1.000000
# Prediccion_review_scores_cleanliness                     0.070960
# Prediccion_bathrooms                                          NaN
# host_response_rate                                       0.105383
# host_is_superhost                                        0.029582
# host_identity_verified                                   0.072727
# property_type                                           -0.140648
# instant_bookable                                         1.000000
# accommodates                                             0.133255
# bathrooms                                                     NaN
# price                                                    0.310926
# review_scores_cleanliness                                0.070960
#
#                                       Prediccion_review_scores_cleanliness  \
# Prediccion_host_response_rate                                     0.107242
# Prediccion_host_is_superhost                                     -0.089403
# Prediccion_host_identity_verified                                -0.100454
# Prediccion_property_type                                          0.013122
# Prediccion_instant_bookable                                       0.070960
# Prediccion_review_scores_cleanliness                              1.000000
# Prediccion_bathrooms                                                   NaN
# host_response_rate                                               -0.107242
# host_is_superhost                                                 0.089403
# host_identity_verified                                           -0.100454
# property_type                                                    -0.013122
# instant_bookable                                                  0.070960
# accommodates                                                      0.008403
# bathrooms                                                              NaN
# price                                                             0.150025
# review_scores_cleanliness                                         1.000000
#
#                                       Prediccion_bathrooms  \
# Prediccion_host_response_rate                          NaN
# Prediccion_host_is_superhost                           NaN
# Prediccion_host_identity_verified                      NaN
# Prediccion_property_type                               NaN
# Prediccion_instant_bookable                            NaN
# Prediccion_review_scores_cleanliness                   NaN
# Prediccion_bathrooms                                   NaN
# host_response_rate                                     NaN
# host_is_superhost                                      NaN
# host_identity_verified                                 NaN
# property_type                                          NaN
# instant_bookable                                       NaN
# accommodates                                           NaN
# bathrooms                                              NaN
# price                                                  NaN
# review_scores_cleanliness                              NaN
#
#                                       host_response_rate  host_is_superhost  \
# Prediccion_host_response_rate                  -1.000000          -0.332690
# Prediccion_host_is_superhost                   -0.332690          -1.000000
# Prediccion_host_identity_verified               0.191014           0.079850
# Prediccion_property_type                        0.040113           0.097426
# Prediccion_instant_bookable                     0.105383           0.029582
# Prediccion_review_scores_cleanliness           -0.107242           0.089403
# Prediccion_bathrooms                                 NaN                NaN
# host_response_rate                              1.000000           0.332690
# host_is_superhost                               0.332690           1.000000
# host_identity_verified                          0.191014           0.079850
# property_type                                  -0.040113          -0.097426
# instant_bookable                                0.105383           0.029582
# accommodates                                    0.045568           0.020784
# bathrooms                                            NaN                NaN
# price                                          -0.132038          -0.100769
# review_scores_cleanliness                      -0.107242           0.089403
#
#                                       host_identity_verified  property_type  \
# Prediccion_host_response_rate                      -0.191014       0.040113
# Prediccion_host_is_superhost                       -0.079850       0.097426
# Prediccion_host_identity_verified                   1.000000      -0.036563
# Prediccion_property_type                            0.036563      -1.000000
# Prediccion_instant_bookable                         0.072727      -0.140648
# Prediccion_review_scores_cleanliness               -0.100454      -0.013122
# Prediccion_bathrooms                                     NaN            NaN
# host_response_rate                                  0.191014      -0.040113
# host_is_superhost                                   0.079850      -0.097426
# host_identity_verified                              1.000000      -0.036563
# property_type                                      -0.036563       1.000000
# instant_bookable                                    0.072727      -0.140648
# accommodates                                        0.023917      -0.067881
# bathrooms                                                NaN            NaN
# price                                               0.030262      -0.132572
# review_scores_cleanliness                          -0.100454      -0.013122
#
#                                       instant_bookable  accommodates  \
# Prediccion_host_response_rate                -0.105383     -0.045568
# Prediccion_host_is_superhost                 -0.029582     -0.020784
# Prediccion_host_identity_verified             0.072727      0.023917
# Prediccion_property_type                      0.140648      0.067881
# Prediccion_instant_bookable                   1.000000      0.133255
# Prediccion_review_scores_cleanliness          0.070960      0.008403
# Prediccion_bathrooms                               NaN           NaN
# host_response_rate                            0.105383      0.045568
# host_is_superhost                             0.029582      0.020784
# host_identity_verified                        0.072727      0.023917
# property_type                                -0.140648     -0.067881
# instant_bookable                              1.000000      0.133255
# accommodates                                  0.133255      1.000000
# bathrooms                                          NaN           NaN
# price                                         0.310926      0.242357
# review_scores_cleanliness                     0.070960      0.008403
#
#                                       bathrooms     price  \
# Prediccion_host_response_rate               NaN  0.132038
# Prediccion_host_is_superhost                NaN  0.100769
# Prediccion_host_identity_verified           NaN  0.030262
# Prediccion_property_type                    NaN  0.132572
# Prediccion_instant_bookable                 NaN  0.310926
# Prediccion_review_scores_cleanliness        NaN  0.150025
# Prediccion_bathrooms                        NaN       NaN
# host_response_rate                          NaN -0.132038
# host_is_superhost                           NaN -0.100769
# host_identity_verified                      NaN  0.030262
# property_type                               NaN -0.132572
# instant_bookable                            NaN  0.310926
# accommodates                                NaN  0.242357
# bathrooms                                   NaN       NaN
# price                                       NaN  1.000000
# review_scores_cleanliness                   NaN  0.150025
#
#                                       review_scores_cleanliness
# Prediccion_host_response_rate                          0.107242
# Prediccion_host_is_superhost                          -0.089403
# Prediccion_host_identity_verified                     -0.100454
# Prediccion_property_type                               0.013122
# Prediccion_instant_bookable                            0.070960
# Prediccion_review_scores_cleanliness                   1.000000
# Prediccion_bathrooms                                        NaN
# host_response_rate                                    -0.107242
# host_is_superhost                                      0.089403
# host_identity_verified                                -0.100454
# property_type                                         -0.013122
# instant_bookable                                       0.070960
# accommodates                                           0.008403
# bathrooms                                                   NaN
# price                                                  0.150025
# review_scores_cleanliness                              1.000000

# %%
#Encontramos el valor absoluto de todas las correlaciones entre las variables 
Corr_Factors1= abs(Corr_Factors)
Corr_Factors1
# Out:
#                                       Prediccion_host_response_rate  \
# Prediccion_host_response_rate                              1.000000
# Prediccion_host_is_superhost                               0.332690
# Prediccion_host_identity_verified                          0.191014
# Prediccion_property_type                                   0.040113
# Prediccion_instant_bookable                                0.105383
# Prediccion_review_scores_cleanliness                       0.107242
# Prediccion_bathrooms                                            NaN
# host_response_rate                                         1.000000
# host_is_superhost                                          0.332690
# host_identity_verified                                     0.191014
# property_type                                              0.040113
# instant_bookable                                           0.105383
# accommodates                                               0.045568
# bathrooms                                                       NaN
# price                                                      0.132038
# review_scores_cleanliness                                  0.107242
#
#                                       Prediccion_host_is_superhost  \
# Prediccion_host_response_rate                             0.332690
# Prediccion_host_is_superhost                              1.000000
# Prediccion_host_identity_verified                         0.079850
# Prediccion_property_type                                  0.097426
# Prediccion_instant_bookable                               0.029582
# Prediccion_review_scores_cleanliness                      0.089403
# Prediccion_bathrooms                                           NaN
# host_response_rate                                        0.332690
# host_is_superhost                                         1.000000
# host_identity_verified                                    0.079850
# property_type                                             0.097426
# instant_bookable                                          0.029582
# accommodates                                              0.020784
# bathrooms                                                      NaN
# price                                                     0.100769
# review_scores_cleanliness                                 0.089403
#
#                                       Prediccion_host_identity_verified  \
# Prediccion_host_response_rate                                  0.191014
# Prediccion_host_is_superhost                                   0.079850
# Prediccion_host_identity_verified                              1.000000
# Prediccion_property_type                                       0.036563
# Prediccion_instant_bookable                                    0.072727
# Prediccion_review_scores_cleanliness                           0.100454
# Prediccion_bathrooms                                                NaN
# host_response_rate                                             0.191014
# host_is_superhost                                              0.079850
# host_identity_verified                                         1.000000
# property_type                                                  0.036563
# instant_bookable                                               0.072727
# accommodates                                                   0.023917
# bathrooms                                                           NaN
# price                                                          0.030262
# review_scores_cleanliness                                      0.100454
#
#                                       Prediccion_property_type  \
# Prediccion_host_response_rate                         0.040113
# Prediccion_host_is_superhost                          0.097426
# Prediccion_host_identity_verified                     0.036563
# Prediccion_property_type                              1.000000
# Prediccion_instant_bookable                           0.140648
# Prediccion_review_scores_cleanliness                  0.013122
# Prediccion_bathrooms                                       NaN
# host_response_rate                                    0.040113
# host_is_superhost                                     0.097426
# host_identity_verified                                0.036563
# property_type                                         1.000000
# instant_bookable                                      0.140648
# accommodates                                          0.067881
# bathrooms                                                  NaN
# price                                                 0.132572
# review_scores_cleanliness                             0.013122
#
#                                       Prediccion_instant_bookable  \
# Prediccion_host_response_rate                            0.105383
# Prediccion_host_is_superhost                             0.029582
# Prediccion_host_identity_verified                        0.072727
# Prediccion_property_type                                 0.140648
# Prediccion_instant_bookable                              1.000000
# Prediccion_review_scores_cleanliness                     0.070960
# Prediccion_bathrooms                                          NaN
# host_response_rate                                       0.105383
# host_is_superhost                                        0.029582
# host_identity_verified                                   0.072727
# property_type                                            0.140648
# instant_bookable                                         1.000000
# accommodates                                             0.133255
# bathrooms                                                     NaN
# price                                                    0.310926
# review_scores_cleanliness                                0.070960
#
#                                       Prediccion_review_scores_cleanliness  \
# Prediccion_host_response_rate                                     0.107242
# Prediccion_host_is_superhost                                      0.089403
# Prediccion_host_identity_verified                                 0.100454
# Prediccion_property_type                                          0.013122
# Prediccion_instant_bookable                                       0.070960
# Prediccion_review_scores_cleanliness                              1.000000
# Prediccion_bathrooms                                                   NaN
# host_response_rate                                                0.107242
# host_is_superhost                                                 0.089403
# host_identity_verified                                            0.100454
# property_type                                                     0.013122
# instant_bookable                                                  0.070960
# accommodates                                                      0.008403
# bathrooms                                                              NaN
# price                                                             0.150025
# review_scores_cleanliness                                         1.000000
#
#                                       Prediccion_bathrooms  \
# Prediccion_host_response_rate                          NaN
# Prediccion_host_is_superhost                           NaN
# Prediccion_host_identity_verified                      NaN
# Prediccion_property_type                               NaN
# Prediccion_instant_bookable                            NaN
# Prediccion_review_scores_cleanliness                   NaN
# Prediccion_bathrooms                                   NaN
# host_response_rate                                     NaN
# host_is_superhost                                      NaN
# host_identity_verified                                 NaN
# property_type                                          NaN
# instant_bookable                                       NaN
# accommodates                                           NaN
# bathrooms                                              NaN
# price                                                  NaN
# review_scores_cleanliness                              NaN
#
#                                       host_response_rate  host_is_superhost  \
# Prediccion_host_response_rate                   1.000000           0.332690
# Prediccion_host_is_superhost                    0.332690           1.000000
# Prediccion_host_identity_verified               0.191014           0.079850
# Prediccion_property_type                        0.040113           0.097426
# Prediccion_instant_bookable                     0.105383           0.029582
# Prediccion_review_scores_cleanliness            0.107242           0.089403
# Prediccion_bathrooms                                 NaN                NaN
# host_response_rate                              1.000000           0.332690
# host_is_superhost                               0.332690           1.000000
# host_identity_verified                          0.191014           0.079850
# property_type                                   0.040113           0.097426
# instant_bookable                                0.105383           0.029582
# accommodates                                    0.045568           0.020784
# bathrooms                                            NaN                NaN
# price                                           0.132038           0.100769
# review_scores_cleanliness                       0.107242           0.089403
#
#                                       host_identity_verified  property_type  \
# Prediccion_host_response_rate                       0.191014       0.040113
# Prediccion_host_is_superhost                        0.079850       0.097426
# Prediccion_host_identity_verified                   1.000000       0.036563
# Prediccion_property_type                            0.036563       1.000000
# Prediccion_instant_bookable                         0.072727       0.140648
# Prediccion_review_scores_cleanliness                0.100454       0.013122
# Prediccion_bathrooms                                     NaN            NaN
# host_response_rate                                  0.191014       0.040113
# host_is_superhost                                   0.079850       0.097426
# host_identity_verified                              1.000000       0.036563
# property_type                                       0.036563       1.000000
# instant_bookable                                    0.072727       0.140648
# accommodates                                        0.023917       0.067881
# bathrooms                                                NaN            NaN
# price                                               0.030262       0.132572
# review_scores_cleanliness                           0.100454       0.013122
#
#                                       instant_bookable  accommodates  \
# Prediccion_host_response_rate                 0.105383      0.045568
# Prediccion_host_is_superhost                  0.029582      0.020784
# Prediccion_host_identity_verified             0.072727      0.023917
# Prediccion_property_type                      0.140648      0.067881
# Prediccion_instant_bookable                   1.000000      0.133255
# Prediccion_review_scores_cleanliness          0.070960      0.008403
# Prediccion_bathrooms                               NaN           NaN
# host_response_rate                            0.105383      0.045568
# host_is_superhost                             0.029582      0.020784
# host_identity_verified                        0.072727      0.023917
# property_type                                 0.140648      0.067881
# instant_bookable                              1.000000      0.133255
# accommodates                                  0.133255      1.000000
# bathrooms                                          NaN           NaN
# price                                         0.310926      0.242357
# review_scores_cleanliness                     0.070960      0.008403
#
#                                       bathrooms     price  \
# Prediccion_host_response_rate               NaN  0.132038
# Prediccion_host_is_superhost                NaN  0.100769
# Prediccion_host_identity_verified           NaN  0.030262
# Prediccion_property_type                    NaN  0.132572
# Prediccion_instant_bookable                 NaN  0.310926
# Prediccion_review_scores_cleanliness        NaN  0.150025
# Prediccion_bathrooms                        NaN       NaN
# host_response_rate                          NaN  0.132038
# host_is_superhost                           NaN  0.100769
# host_identity_verified                      NaN  0.030262
# property_type                               NaN  0.132572
# instant_bookable                            NaN  0.310926
# accommodates                                NaN  0.242357
# bathrooms                                   NaN       NaN
# price                                       NaN  1.000000
# review_scores_cleanliness                   NaN  0.150025
#
#                                       review_scores_cleanliness
# Prediccion_host_response_rate                          0.107242
# Prediccion_host_is_superhost                           0.089403
# Prediccion_host_identity_verified                      0.100454
# Prediccion_property_type                               0.013122
# Prediccion_instant_bookable                            0.070960
# Prediccion_review_scores_cleanliness                   1.000000
# Prediccion_bathrooms                                        NaN
# host_response_rate                                     0.107242
# host_is_superhost                                      0.089403
# host_identity_verified                                 0.100454
# property_type                                          0.013122
# instant_bookable                                       0.070960
# accommodates                                           0.008403
# bathrooms                                                   NaN
# price                                                  0.150025
# review_scores_cleanliness                              1.000000

# %%
#Graficamos el mapa de calor de las coeficientes de correlación 
Heart_Nap = sns.heatmap(Corr_Factors1, cmap= 'coolwarm')
Heart_Nap
# Out:
# <Axes: >

# %%
#Ajustamos el mapa de calor de las coeficientes de correlación 
plt.figure(figsize=(12,8))
Heart_Nap = sns.heatmap(Corr_Factors1, cmap= 'Oranges', annot=True, fmt=".2f")
Heart_Nap
# Out:
# <Axes: >

# %%
# Obtener R2
r2_1 = model.score(Var_Indep, Var_Dep)
r2_2 = model2.score(Var_Indep2, Var_Dep)
r2_3 = model3.score(Var_Indep3, Var_Dep)
r2_4 = model4.score(Var_Indep4, Var_Dep)
r2_5 = model5.score(Var_Indep5, Var_Dep)
r2_6 = model6.score(Var_Indep6, Var_Dep)
r2_7 = model7.score(Var_Indep7, Var_Dep)
r2_8 = model8.score(Var_Indep8, Var_Dep2)

# Guardar los resultados 
r2_values = {
    "host_response_rate": r2_1,
    "host_is_superhost": r2_2,
    "room_type": r2_3,
    "host_identity_verified": r2_4,
    "property_type": r2_5,
    "instant_bookable": r2_6,
    "review_scores_cleanliness": r2_7,
    "bathrooms": r2_8
}

# tres mejores variables
top_3 = sorted(r2_values.items(), key=lambda x: x[1], reverse=True)[:3]
print("Las variables con mayor correlación son:")
for variable, r2 in top_3:
    print(f"{variable}: R² = {r2:.4f}")
# Out:
# Las variables con mayor correlación son:
# instant_bookable: R² = 0.0967
# review_scores_cleanliness: R² = 0.0225
# property_type: R² = 0.0176
