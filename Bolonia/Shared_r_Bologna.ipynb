# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#cargar archivo desde seaborn 
df=pd.read_csv('Bologna_clean.csv')
#eliminamos la columna unnamed 
df= df.drop(['Unnamed: 0'], axis=1)
df.head(5)
# Out:
#                            listing_url  \
# 0   https://www.airbnb.com/rooms/42196
# 1   https://www.airbnb.com/rooms/46352
# 2   https://www.airbnb.com/rooms/85368
# 3  https://www.airbnb.com/rooms/204553
# 4  https://www.airbnb.com/rooms/219878
#
#                                                name  \
# 0               50 sm Studio in the historic centre
# 1                        A room in Pasolini's house
# 2                              Garden House Bologna
# 3  Private Room & Bath Ex-Convent in Centro Storico
# 4                  Gorgeous Haven in Centro Storico
#
#                                          description  \
# 0  The studio is a fully restored ancient basemen...
# 1  Simple, cozy and silent room in a lived house ...
# 2                      No se proporciona descripción
# 3  The neighbourhood is the most prestigious of B...
# 4  Quiet, bright, fully equipped 800 square feet ...
#
#                                neighborhood_overview  \
# 0                        No se proporcionan detalles
# 1  In the very nearby you have Via Saragozza and ...
# 2                        No se proporcionan detalles
# 3  Safest, most central, quietest street in Bolog...
# 4  has many shops, cafes, wine bars, restaurants ...
#
#                                          picture_url   host_name  host_since  \
# 0  https://a0.muscache.com/pictures/4775726/68044...       Carlo  2010-07-29
# 1  https://a0.muscache.com/pictures/9f94acc3-98fc...    Eleonora  2011-03-28
# 2  https://a0.muscache.com/pictures/585815/331d45...  Anna Maria  2011-03-28
# 3  https://a0.muscache.com/pictures/36151297/8be9...   Elizabeth  2011-05-09
# 4  https://a0.muscache.com/pictures/f16e5b7e-68b3...       Elisa  2011-09-10
#
#    host_response_time host_response_rate host_is_superhost  ...  \
# 0      within an hour               100%                 f  ...
# 1  a few days or more                44%                 f  ...
# 2         Desconocido                 -%                 f  ...
# 3      within an hour               100%                 f  ...
# 4  within a few hours               100%                 t  ...
#
#   review_scores_cleanliness review_scores_checkin review_scores_communication  \
# 0                      4.65                  4.92                        4.88
# 1                      4.60                  4.83                        4.85
# 2                      4.83                  4.98                        4.98
# 3                      4.92                  4.94                        4.93
# 4                      4.95                  4.90                        4.92
#
#   review_scores_location review_scores_value calculated_host_listings_count  \
# 0                   4.87                4.66                            2.0
# 1                   4.84                4.67                            2.0
# 2                   4.80                4.81                            1.0
# 3                   4.97                4.86                            1.0
# 4                   4.84                4.78                            2.0
#
#   calculated_host_listings_count_entire_homes  \
# 0                                         2.0
# 1                                         0.0
# 2                                         1.0
# 3                                         0.0
# 4                                         2.0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                          0.0
# 1                                          2.0
# 2                                          0.0
# 3                                          1.0
# 4                                          0.0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                         0.0              1.37
# 1                                         0.0              2.57
# 2                                         0.0              0.39
# 3                                         0.0              1.68
# 4                                         0.0              1.09
#
# [5 rows x 50 columns]

# %%
f1=df.iloc[ :  , [8,9,10,13,14,20,24,25,28,40] ]
f1
# Out:
#      host_response_rate host_is_superhost host_identity_verified  \
# 0                  100%                 f                      t
# 1                   44%                 f                      t
# 2                    -%                 f                      t
# 3                  100%                 f                      t
# 4                  100%                 t                      t
# ...                 ...               ...                    ...
# 4838               100%                 f                      f
# 4839               100%                 f                      t
# 4840                 -%                 f                      f
# 4841               100%                 f                      t
# 4842                 -%                 f                      t
#
#                     property_type        room_type instant_bookable  \
# 0              Entire rental unit  Entire home/apt                t
# 1     Private room in rental unit     Private room                f
# 2              Entire rental unit  Entire home/apt                f
# 3     Private room in rental unit     Private room                f
# 4              Entire rental unit  Entire home/apt                f
# ...                           ...              ...              ...
# 4838         Private room in home     Private room                f
# 4839           Entire rental unit  Entire home/apt                f
# 4840           Entire rental unit  Entire home/apt                t
# 4841           Entire rental unit  Entire home/apt                f
# 4842           Entire rental unit  Entire home/apt                t
#
#       accommodates  bathrooms  price  review_scores_cleanliness
# 0              2.0        1.0   80.0                       4.65
# 1              2.0        1.0   43.0                       4.60
# 2              5.0        1.0  120.0                       4.83
# 3              2.0        1.0   92.0                       4.92
# 4              2.0        1.0  147.0                       4.95
# ...            ...        ...    ...                        ...
# 4838           2.0        1.0   70.0                       5.00
# 4839           5.0        1.0  254.0                       5.00
# 4840           4.0        1.0   84.0                       5.00
# 4841           2.0        1.0  100.0                       5.00
# 4842           5.0        1.0  240.0                       5.00
#
# [4843 rows x 10 columns]

# %%
#convertimos string a tipos numéricos
f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})

#from sklearn.preprocessing import LabelEncoder
#encoder = LabelEncoder()
#f1['property_type'] = encoder.fit_transform(f1['property_type'])
#f1['property_type'] = f1['property_type'].astype(float)

frecuencias = f1['property_type'].value_counts()
f1['property_type'] = f1['property_type'].map(frecuencias)


f1['host_response_rate'] = f1['host_response_rate'].astype(str).str.rstrip('%')
f1['host_response_rate'] = pd.to_numeric(f1['host_response_rate'], errors='coerce').fillna(0)

f1['room_type'] = f1['room_type'].map({
    'Entire home/apt': 1,
    'Private room': 2,
    'Shared room': 3,
    'Hotel room': 4
})

f1['price'] = f1['price'].astype(str).str.rstrip('$')
f1['price'] = pd.to_numeric(f1['price'], errors='coerce').fillna(0)
# Out:
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_16996\1986825469.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_16996\1986825469.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_16996\1986825469.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_16996\1986825469.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_16996\1986825469.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_16996\1986825469.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_16996\1986825469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['property_type'] = f1['property_type'].map(frecuencias)
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_16996\1986825469.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_response_rate'] = f1['host_response_rate'].astype(str).str.rstrip('%')
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_16996\1986825469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_response_rate'] = pd.to_numeric(f1['host_response_rate'], errors='coerce').fillna(0)
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_16996\1986825469.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['room_type'] = f1['room_type'].map({
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_16996\1986825469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['price'] = f1['price'].astype(str).str.rstrip('$')
# C:\Users\pplcf\AppData\Local\Temp\ipykernel_16996\1986825469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['price'] = pd.to_numeric(f1['price'], errors='coerce').fillna(0)

# %%
#f2 = Shared room
f2= f1[(f1["room_type"] == 4)]

# %%
f2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 69 to 1370
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   host_response_rate         6 non-null      float64
#  1   host_is_superhost          6 non-null      int64
#  2   host_identity_verified     6 non-null      int64
#  3   property_type              6 non-null      int64
#  4   room_type                  6 non-null      int64
#  5   instant_bookable           6 non-null      int64
#  6   accommodates               6 non-null      float64
#  7   bathrooms                  6 non-null      float64
#  8   price                      6 non-null      float64
#  9   review_scores_cleanliness  6 non-null      float64
# dtypes: float64(5), int64(5)
# memory usage: 528.0 bytes

# %%
#imprimimos el scatter plot entre la variable dependiente total e independiente (a)
#para observar el comportamiento en su dispersión 

from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='host_response_rate', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='host_is_superhost', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='host_identity_verified', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='property_type', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='room_type', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='instant_bookable', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='review_scores_cleanliness', y='price', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color 

sns.scatterplot(x='room_type', y='accommodates', color='blue', data=f2)
sns.scatterplot(x='bathrooms', y='accommodates', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='accommodates'>

# %% [markdown]
# **DECLARACIÓN DE VARIABLES INDEPENDIENTES Y DEPENDIENTES**

# %%
#declaración de las variables independientes que se van a comparar con el precio 
Var_Indep= f2[['host_response_rate']]
Var_Indep2=f2[['host_is_superhost']]
Var_Indep3=f2[['room_type']]
Var_Indep4=f2[['host_identity_verified']]
Var_Indep5= f2[['property_type']]
Var_Indep6= f2[['instant_bookable']]
Var_Indep7= f2[['review_scores_cleanliness']]
#declaración de variable independiente para accommodates 
Var_Indep8= f2[['bathrooms']]

# %%
#variables independientes para la regresión lineal
Var_Dep= f2['price']
Var_Dep2= f2['accommodates']

# %% [markdown]
# **DEFINICIÓN DEL MODELO**

# %%
#se define model como función de regresión lineal 
from sklearn.linear_model import LinearRegression 
model=LinearRegression()
model2=LinearRegression()
model3=LinearRegression()
model4=LinearRegression()
model5=LinearRegression()
model6=LinearRegression()
model7=LinearRegression()
model8=LinearRegression()

# %%
#verficamos la función relacionada al modelo 
type(model)
type(model2)
type(model3)
type(model4)
type(model5)
type(model6)
type(model7)
type(model8)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#ajustamos el modelo con las variables antes declaradas
model.fit(X=Var_Indep, y=Var_Dep)
model2.fit(X=Var_Indep2, y=Var_Dep)
model3.fit(X=Var_Indep3, y=Var_Dep)
model4.fit(X=Var_Indep4, y=Var_Dep)
model5.fit(X=Var_Indep5, y=Var_Dep)
model6.fit(X=Var_Indep6, y=Var_Dep)
model7.fit(X=Var_Indep7, y=Var_Dep)
model8.fit(X=Var_Indep8, y=Var_Dep2)
# Out:
# LinearRegression()

# %% [markdown]
# **COEFICIENTES OBTENIDOS PARA NUESTROS MODELOS**

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-0.433]),
#  'rank_': 1,
#  'singular_': array([91.28709292]),
#  'intercept_': np.float64(148.3)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model2.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_is_superhost'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-43.3]),
#  'rank_': 1,
#  'singular_': array([0.91287093]),
#  'intercept_': np.float64(148.3)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model3.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['room_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.]),
#  'rank_': 0,
#  'singular_': array([0.]),
#  'intercept_': np.float64(141.08333333333334)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model4.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_identity_verified'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.]),
#  'rank_': 0,
#  'singular_': array([0.]),
#  'intercept_': np.float64(141.08333333333334)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model5.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['property_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.]),
#  'rank_': 0,
#  'singular_': array([0.]),
#  'intercept_': np.float64(141.08333333333334)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model6.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['instant_bookable'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-2.15]),
#  'rank_': 1,
#  'singular_': array([1.15470054]),
#  'intercept_': np.float64(141.8)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model7.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([19.34419263]),
#  'rank_': 1,
#  'singular_': array([0.48511167]),
#  'intercept_': np.float64(47.77984419263511)}

# %%
#verificamos los coeficientes obtenidos para el modelo ajustado 
model8.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['bathrooms'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.]),
#  'rank_': 0,
#  'singular_': array([0.]),
#  'intercept_': np.float64(2.1666666666666665)}

# %% [markdown]
# **A PARTIR DE AQUÍ PREDECIMOS VALORES DE ACUERDO AL MODELO MATEMÁTICO**

# %% [markdown]
# **Modelo matemático y=-0.94114872x + 1327.7330443080114**

# %%
#predecimos valores
y_pred= model.predict(X=f2[['host_response_rate']])
y_pred
# Out:
# array([148.3, 105. , 148.3, 148.3, 148.3, 148.3])

# %% [markdown]
# **Modelo matemático y=21.00986237x + 1237.7516553524084**

# %%
#predecimos valores
y_pred2= model2.predict(X=f2[['host_is_superhost']])
y_pred2
# Out:
# array([148.3, 105. , 148.3, 148.3, 148.3, 148.3])

# %% [markdown]
# **Modelo matemático y=0x + 11247.1754189944133**

# %%
#predecimos valores
y_pred3= model3.predict(X=f2[['room_type']])
y_pred3
# Out:
# array([141.08333333, 141.08333333, 141.08333333, 141.08333333,
#        141.08333333, 141.08333333])

# %% [markdown]
# **Modelo matemático y=-112.80942578x + 1357.171593533486**

# %%
#predecimos valores
y_pred4= model4.predict(X=f2[['host_identity_verified']])
y_pred4
# Out:
# array([141.08333333, 141.08333333, 141.08333333, 141.08333333,
#        141.08333333, 141.08333333])

# %% [markdown]
# **Modelo matemático y=-4.56100445x + 1325.0492572068565**

# %%
#predecimos valores
y_pred5= model5.predict(X=f2[['property_type']])
y_pred5
# Out:
# array([141.08333333, 141.08333333, 141.08333333, 141.08333333,
#        141.08333333, 141.08333333])

# %% [markdown]
# **Modelo matemático y=71.48464608x + 1217.0755372065255**

# %%
#predecimos valores
y_pred6= model6.predict(X=f2[['instant_bookable']])
y_pred6
# Out:
# array([139.65, 139.65, 141.8 , 141.8 , 141.8 , 141.8 ])

# %% [markdown]
# **Modelo matemático y=381.28956491x + -604.4218714343112**

# %%
y_pred7= model7.predict(X=f2[['review_scores_cleanliness']])
y_pred7
# Out:
# array([144.50080737, 144.11392351, 141.01885269, 138.1172238 ,
#        134.24838527, 144.50080737])

# %% [markdown]
# **Modelo matemático y=0.97488088x + 2.1063441944025767**

# %%
y_pred8= model8.predict(X=f2[['bathrooms']])
y_pred8
# Out:
# array([2.16666667, 2.16666667, 2.16666667, 2.16666667, 2.16666667,
#        2.16666667])

# %% [markdown]
# **INSERTAMOS LA COLUMNA DE PREDICCIONES A NUESTRO DATAFRAME**

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(0, 'Prediccion_host_response_rate', y_pred)
f2
# Out:
#       Prediccion_host_response_rate  host_response_rate  host_is_superhost  \
# 69                            148.3                 0.0                  0
# 669                           105.0               100.0                  1
# 1228                          148.3                 0.0                  0
# 1229                          148.3                 0.0                  0
# 1238                          148.3                 0.0                  0
# 1370                          148.3                 0.0                  0
#
#       host_identity_verified  property_type  room_type  instant_bookable  \
# 69                         1              6          4                 1
# 669                        1              6          4                 1
# 1228                       1              6          4                 0
# 1229                       1              6          4                 0
# 1238                       1              6          4                 0
# 1370                       1              6          4                 0
#
#       accommodates  bathrooms  price  review_scores_cleanliness
# 69             2.0        1.0  174.3                       5.00
# 669            3.0        1.0  105.0                       4.98
# 1228           2.0        1.0  137.4                       4.82
# 1229           2.0        1.0  137.4                       4.67
# 1238           2.0        1.0  137.4                       4.47
# 1370           2.0        1.0  155.0                       5.00

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(1, 'Prediccion_host_is_superhost', y_pred2)
f2
# Out:
#       Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 69                            148.3                         148.3
# 669                           105.0                         105.0
# 1228                          148.3                         148.3
# 1229                          148.3                         148.3
# 1238                          148.3                         148.3
# 1370                          148.3                         148.3
#
#       host_response_rate  host_is_superhost  host_identity_verified  \
# 69                   0.0                  0                       1
# 669                100.0                  1                       1
# 1228                 0.0                  0                       1
# 1229                 0.0                  0                       1
# 1238                 0.0                  0                       1
# 1370                 0.0                  0                       1
#
#       property_type  room_type  instant_bookable  accommodates  bathrooms  \
# 69                6          4                 1           2.0        1.0
# 669               6          4                 1           3.0        1.0
# 1228              6          4                 0           2.0        1.0
# 1229              6          4                 0           2.0        1.0
# 1238              6          4                 0           2.0        1.0
# 1370              6          4                 0           2.0        1.0
#
#       price  review_scores_cleanliness
# 69    174.3                       5.00
# 669   105.0                       4.98
# 1228  137.4                       4.82
# 1229  137.4                       4.67
# 1238  137.4                       4.47
# 1370  155.0                       5.00

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(2, 'Prediccion_room_type', y_pred3)
f2
# Out:
#       Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 69                            148.3                         148.3
# 669                           105.0                         105.0
# 1228                          148.3                         148.3
# 1229                          148.3                         148.3
# 1238                          148.3                         148.3
# 1370                          148.3                         148.3
#
#       Prediccion_room_type  host_response_rate  host_is_superhost  \
# 69              141.083333                 0.0                  0
# 669             141.083333               100.0                  1
# 1228            141.083333                 0.0                  0
# 1229            141.083333                 0.0                  0
# 1238            141.083333                 0.0                  0
# 1370            141.083333                 0.0                  0
#
#       host_identity_verified  property_type  room_type  instant_bookable  \
# 69                         1              6          4                 1
# 669                        1              6          4                 1
# 1228                       1              6          4                 0
# 1229                       1              6          4                 0
# 1238                       1              6          4                 0
# 1370                       1              6          4                 0
#
#       accommodates  bathrooms  price  review_scores_cleanliness
# 69             2.0        1.0  174.3                       5.00
# 669            3.0        1.0  105.0                       4.98
# 1228           2.0        1.0  137.4                       4.82
# 1229           2.0        1.0  137.4                       4.67
# 1238           2.0        1.0  137.4                       4.47
# 1370           2.0        1.0  155.0                       5.00

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(3, 'Prediccion_host_identity_verified', y_pred4)
f2
# Out:
#       Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 69                            148.3                         148.3
# 669                           105.0                         105.0
# 1228                          148.3                         148.3
# 1229                          148.3                         148.3
# 1238                          148.3                         148.3
# 1370                          148.3                         148.3
#
#       Prediccion_room_type  Prediccion_host_identity_verified  \
# 69              141.083333                         141.083333
# 669             141.083333                         141.083333
# 1228            141.083333                         141.083333
# 1229            141.083333                         141.083333
# 1238            141.083333                         141.083333
# 1370            141.083333                         141.083333
#
#       host_response_rate  host_is_superhost  host_identity_verified  \
# 69                   0.0                  0                       1
# 669                100.0                  1                       1
# 1228                 0.0                  0                       1
# 1229                 0.0                  0                       1
# 1238                 0.0                  0                       1
# 1370                 0.0                  0                       1
#
#       property_type  room_type  instant_bookable  accommodates  bathrooms  \
# 69                6          4                 1           2.0        1.0
# 669               6          4                 1           3.0        1.0
# 1228              6          4                 0           2.0        1.0
# 1229              6          4                 0           2.0        1.0
# 1238              6          4                 0           2.0        1.0
# 1370              6          4                 0           2.0        1.0
#
#       price  review_scores_cleanliness
# 69    174.3                       5.00
# 669   105.0                       4.98
# 1228  137.4                       4.82
# 1229  137.4                       4.67
# 1238  137.4                       4.47
# 1370  155.0                       5.00

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(4, 'Prediccion_property_type', y_pred5)
f2
# Out:
#       Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 69                            148.3                         148.3
# 669                           105.0                         105.0
# 1228                          148.3                         148.3
# 1229                          148.3                         148.3
# 1238                          148.3                         148.3
# 1370                          148.3                         148.3
#
#       Prediccion_room_type  Prediccion_host_identity_verified  \
# 69              141.083333                         141.083333
# 669             141.083333                         141.083333
# 1228            141.083333                         141.083333
# 1229            141.083333                         141.083333
# 1238            141.083333                         141.083333
# 1370            141.083333                         141.083333
#
#       Prediccion_property_type  host_response_rate  host_is_superhost  \
# 69                  141.083333                 0.0                  0
# 669                 141.083333               100.0                  1
# 1228                141.083333                 0.0                  0
# 1229                141.083333                 0.0                  0
# 1238                141.083333                 0.0                  0
# 1370                141.083333                 0.0                  0
#
#       host_identity_verified  property_type  room_type  instant_bookable  \
# 69                         1              6          4                 1
# 669                        1              6          4                 1
# 1228                       1              6          4                 0
# 1229                       1              6          4                 0
# 1238                       1              6          4                 0
# 1370                       1              6          4                 0
#
#       accommodates  bathrooms  price  review_scores_cleanliness
# 69             2.0        1.0  174.3                       5.00
# 669            3.0        1.0  105.0                       4.98
# 1228           2.0        1.0  137.4                       4.82
# 1229           2.0        1.0  137.4                       4.67
# 1238           2.0        1.0  137.4                       4.47
# 1370           2.0        1.0  155.0                       5.00

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(5, 'Prediccion_instant_bookable', y_pred6)
f2
# Out:
#       Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 69                            148.3                         148.3
# 669                           105.0                         105.0
# 1228                          148.3                         148.3
# 1229                          148.3                         148.3
# 1238                          148.3                         148.3
# 1370                          148.3                         148.3
#
#       Prediccion_room_type  Prediccion_host_identity_verified  \
# 69              141.083333                         141.083333
# 669             141.083333                         141.083333
# 1228            141.083333                         141.083333
# 1229            141.083333                         141.083333
# 1238            141.083333                         141.083333
# 1370            141.083333                         141.083333
#
#       Prediccion_property_type  Prediccion_instant_bookable  \
# 69                  141.083333                       139.65
# 669                 141.083333                       139.65
# 1228                141.083333                       141.80
# 1229                141.083333                       141.80
# 1238                141.083333                       141.80
# 1370                141.083333                       141.80
#
#       host_response_rate  host_is_superhost  host_identity_verified  \
# 69                   0.0                  0                       1
# 669                100.0                  1                       1
# 1228                 0.0                  0                       1
# 1229                 0.0                  0                       1
# 1238                 0.0                  0                       1
# 1370                 0.0                  0                       1
#
#       property_type  room_type  instant_bookable  accommodates  bathrooms  \
# 69                6          4                 1           2.0        1.0
# 669               6          4                 1           3.0        1.0
# 1228              6          4                 0           2.0        1.0
# 1229              6          4                 0           2.0        1.0
# 1238              6          4                 0           2.0        1.0
# 1370              6          4                 0           2.0        1.0
#
#       price  review_scores_cleanliness
# 69    174.3                       5.00
# 669   105.0                       4.98
# 1228  137.4                       4.82
# 1229  137.4                       4.67
# 1238  137.4                       4.47
# 1370  155.0                       5.00

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(6, 'Prediccion_review_scores_cleanliness', y_pred7)
f2
# Out:
#       Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 69                            148.3                         148.3
# 669                           105.0                         105.0
# 1228                          148.3                         148.3
# 1229                          148.3                         148.3
# 1238                          148.3                         148.3
# 1370                          148.3                         148.3
#
#       Prediccion_room_type  Prediccion_host_identity_verified  \
# 69              141.083333                         141.083333
# 669             141.083333                         141.083333
# 1228            141.083333                         141.083333
# 1229            141.083333                         141.083333
# 1238            141.083333                         141.083333
# 1370            141.083333                         141.083333
#
#       Prediccion_property_type  Prediccion_instant_bookable  \
# 69                  141.083333                       139.65
# 669                 141.083333                       139.65
# 1228                141.083333                       141.80
# 1229                141.083333                       141.80
# 1238                141.083333                       141.80
# 1370                141.083333                       141.80
#
#       Prediccion_review_scores_cleanliness  host_response_rate  \
# 69                              144.500807                 0.0
# 669                             144.113924               100.0
# 1228                            141.018853                 0.0
# 1229                            138.117224                 0.0
# 1238                            134.248385                 0.0
# 1370                            144.500807                 0.0
#
#       host_is_superhost  host_identity_verified  property_type  room_type  \
# 69                    0                       1              6          4
# 669                   1                       1              6          4
# 1228                  0                       1              6          4
# 1229                  0                       1              6          4
# 1238                  0                       1              6          4
# 1370                  0                       1              6          4
#
#       instant_bookable  accommodates  bathrooms  price  \
# 69                   1           2.0        1.0  174.3
# 669                  1           3.0        1.0  105.0
# 1228                 0           2.0        1.0  137.4
# 1229                 0           2.0        1.0  137.4
# 1238                 0           2.0        1.0  137.4
# 1370                 0           2.0        1.0  155.0
#
#       review_scores_cleanliness
# 69                         5.00
# 669                        4.98
# 1228                       4.82
# 1229                       4.67
# 1238                       4.47
# 1370                       5.00

# %%
#insertamos la columna de predicciones en el DataFrame 
f2.insert(7, 'Prediccion_bathrooms', y_pred8)
f2
# Out:
#       Prediccion_host_response_rate  Prediccion_host_is_superhost  \
# 69                            148.3                         148.3
# 669                           105.0                         105.0
# 1228                          148.3                         148.3
# 1229                          148.3                         148.3
# 1238                          148.3                         148.3
# 1370                          148.3                         148.3
#
#       Prediccion_room_type  Prediccion_host_identity_verified  \
# 69              141.083333                         141.083333
# 669             141.083333                         141.083333
# 1228            141.083333                         141.083333
# 1229            141.083333                         141.083333
# 1238            141.083333                         141.083333
# 1370            141.083333                         141.083333
#
#       Prediccion_property_type  Prediccion_instant_bookable  \
# 69                  141.083333                       139.65
# 669                 141.083333                       139.65
# 1228                141.083333                       141.80
# 1229                141.083333                       141.80
# 1238                141.083333                       141.80
# 1370                141.083333                       141.80
#
#       Prediccion_review_scores_cleanliness  Prediccion_bathrooms  \
# 69                              144.500807              2.166667
# 669                             144.113924              2.166667
# 1228                            141.018853              2.166667
# 1229                            138.117224              2.166667
# 1238                            134.248385              2.166667
# 1370                            144.500807              2.166667
#
#       host_response_rate  host_is_superhost  host_identity_verified  \
# 69                   0.0                  0                       1
# 669                100.0                  1                       1
# 1228                 0.0                  0                       1
# 1229                 0.0                  0                       1
# 1238                 0.0                  0                       1
# 1370                 0.0                  0                       1
#
#       property_type  room_type  instant_bookable  accommodates  bathrooms  \
# 69                6          4                 1           2.0        1.0
# 669               6          4                 1           3.0        1.0
# 1228              6          4                 0           2.0        1.0
# 1229              6          4                 0           2.0        1.0
# 1238              6          4                 0           2.0        1.0
# 1370              6          4                 0           2.0        1.0
#
#       price  review_scores_cleanliness
# 69    174.3                       5.00
# 669   105.0                       4.98
# 1228  137.4                       4.82
# 1229  137.4                       4.67
# 1238  137.4                       4.47
# 1370  155.0                       5.00

# %% [markdown]
# **GRÁFICAS COMPARATIVAS**

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='host_response_rate', y='price', color='blue', data=f2)
sns.scatterplot(x='host_response_rate', y='Prediccion_host_response_rate', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='host_is_superhost', y='price', color='blue', data=f2)
sns.scatterplot(x='host_is_superhost', y='Prediccion_host_is_superhost', color='red', data=f2)
#sns.lineplot(x='host_is_superhost', y='Predicciones2', color='red', data=f2)
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='room_type', y='price', color='blue', data=f2)
sns.scatterplot(x='room_type', y='Prediccion_room_type', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='host_identity_verified', y='price', color='blue', data=f2)
sns.scatterplot(x='host_identity_verified', y='Prediccion_host_identity_verified', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='host_identity_verified', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='property_type', y='price', color='blue', data=f2)
sns.scatterplot(x='property_type', y='Prediccion_property_type', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='instant_bookable', y='price', color='blue', data=f2)
sns.scatterplot(x='instant_bookable', y='Prediccion_instant_bookable', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='instant_bookable', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='review_scores_cleanliness', y='price', color='blue', data=f2)
sns.scatterplot(x='review_scores_cleanliness', y='Prediccion_review_scores_cleanliness', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='price'>

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido 

sns.scatterplot(x='bathrooms', y='accommodates', color='blue', data=f2)
sns.scatterplot(x='bathrooms', y='Prediccion_bathrooms', color='red', data=f2)
#sns.lineplot(x='host_response_rate', y='Predicciones1', color='red', data=f2)
# Out:
# <Axes: xlabel='bathrooms', ylabel='accommodates'>

# %% [markdown]
# **COEFICIENTES DE DETERMINACIÓN**

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter= model.score(X=Var_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.5918822454583393

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter2= model2.score(X=Var_Indep2, y=Var_Dep)
coef_Deter2
# Out:
# 0.5918822454583393

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter3= model3.score(X=Var_Indep3, y=Var_Dep)
coef_Deter3
# Out:
# 0.0

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter4= model4.score(X=Var_Indep4, y=Var_Dep)
coef_Deter4
# Out:
# 0.0

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter5= model5.score(X=Var_Indep5, y=Var_Dep)
coef_Deter5
# Out:
# 0.0

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter6= model6.score(X=Var_Indep6, y=Var_Dep)
coef_Deter6
# Out:
# 0.002334836223676695

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter7= model7.score(X=Var_Indep7, y=Var_Dep)
coef_Deter7
# Out:
# 0.03335995292573557

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter8= model8.score(X=Var_Indep8, y=Var_Dep2)
coef_Deter8
# Out:
# 0.0

# %% [markdown]
# **COEFICIENTES DE CORRELACIÓN**

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.7693388365722474)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl2=np.sqrt(coef_Deter2)
coef_Correl2
# Out:
# np.float64(0.7693388365722474)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl3=np.sqrt(coef_Deter2)
coef_Correl3
# Out:
# np.float64(0.7693388365722474)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl4=np.sqrt(coef_Deter4)
coef_Correl4
# Out:
# np.float64(0.0)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl5=np.sqrt(coef_Deter5)
coef_Correl5
# Out:
# np.float64(0.0)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl6=np.sqrt(coef_Deter6)
coef_Correl6
# Out:
# np.float64(0.04832014304280043)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl7=np.sqrt(coef_Deter7)
coef_Correl7
# Out:
# np.float64(0.18264707204260233)

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl8=np.sqrt(coef_Deter8)
coef_Correl8
# Out:
# np.float64(0.0)

# %%
#eliminamos room_type y su prediccion 

f2= f2.drop(['room_type', 'Prediccion_room_type' ], axis=1)

# %%
#Graficamos todas las dispersiones entre todas las variables
sns.pairplot(f2)

# %%
#Analizar categorias de una columna
df6 = f2.groupby(['host_response_rate'])['host_response_rate'].count()
df6
# Out:
# host_response_rate
# 0.0      5
# 100.0    1
# Name: host_response_rate, dtype: int64

# %%
#Encontramos todas las correlaciones entre las variables 
Corr_Factors= f2.corr()
Corr_Factors
# Out:
#                                       Prediccion_host_response_rate  \
# Prediccion_host_response_rate                              1.000000
# Prediccion_host_is_superhost                               1.000000
# Prediccion_host_identity_verified                               NaN
# Prediccion_property_type                                        NaN
# Prediccion_instant_bookable                                0.632456
# Prediccion_review_scores_cleanliness                      -0.353774
# Prediccion_bathrooms                                            NaN
# host_response_rate                                        -1.000000
# host_is_superhost                                         -1.000000
# host_identity_verified                                          NaN
# property_type                                                   NaN
# instant_bookable                                          -0.632456
# accommodates                                              -1.000000
# bathrooms                                                       NaN
# price                                                      0.769339
# review_scores_cleanliness                                 -0.353774
#
#                                       Prediccion_host_is_superhost  \
# Prediccion_host_response_rate                             1.000000
# Prediccion_host_is_superhost                              1.000000
# Prediccion_host_identity_verified                              NaN
# Prediccion_property_type                                       NaN
# Prediccion_instant_bookable                               0.632456
# Prediccion_review_scores_cleanliness                     -0.353774
# Prediccion_bathrooms                                           NaN
# host_response_rate                                       -1.000000
# host_is_superhost                                        -1.000000
# host_identity_verified                                         NaN
# property_type                                                  NaN
# instant_bookable                                         -0.632456
# accommodates                                             -1.000000
# bathrooms                                                      NaN
# price                                                     0.769339
# review_scores_cleanliness                                -0.353774
#
#                                       Prediccion_host_identity_verified  \
# Prediccion_host_response_rate                                       NaN
# Prediccion_host_is_superhost                                        NaN
# Prediccion_host_identity_verified                                   NaN
# Prediccion_property_type                                            NaN
# Prediccion_instant_bookable                                         NaN
# Prediccion_review_scores_cleanliness                                NaN
# Prediccion_bathrooms                                                NaN
# host_response_rate                                                  NaN
# host_is_superhost                                                   NaN
# host_identity_verified                                              NaN
# property_type                                                       NaN
# instant_bookable                                                    NaN
# accommodates                                                        NaN
# bathrooms                                                           NaN
# price                                                               NaN
# review_scores_cleanliness                                           NaN
#
#                                       Prediccion_property_type  \
# Prediccion_host_response_rate                              NaN
# Prediccion_host_is_superhost                               NaN
# Prediccion_host_identity_verified                          NaN
# Prediccion_property_type                                   NaN
# Prediccion_instant_bookable                                NaN
# Prediccion_review_scores_cleanliness                       NaN
# Prediccion_bathrooms                                       NaN
# host_response_rate                                         NaN
# host_is_superhost                                          NaN
# host_identity_verified                                     NaN
# property_type                                              NaN
# instant_bookable                                           NaN
# accommodates                                               NaN
# bathrooms                                                  NaN
# price                                                      NaN
# review_scores_cleanliness                                  NaN
#
#                                       Prediccion_instant_bookable  \
# Prediccion_host_response_rate                            0.632456
# Prediccion_host_is_superhost                             0.632456
# Prediccion_host_identity_verified                             NaN
# Prediccion_property_type                                      NaN
# Prediccion_instant_bookable                              1.000000
# Prediccion_review_scores_cleanliness                    -0.595069
# Prediccion_bathrooms                                          NaN
# host_response_rate                                      -0.632456
# host_is_superhost                                       -0.632456
# host_identity_verified                                        NaN
# property_type                                                 NaN
# instant_bookable                                        -1.000000
# accommodates                                            -0.632456
# bathrooms                                                     NaN
# price                                                    0.048320
# review_scores_cleanliness                               -0.595069
#
#                                       Prediccion_review_scores_cleanliness  \
# Prediccion_host_response_rate                                    -0.353774
# Prediccion_host_is_superhost                                     -0.353774
# Prediccion_host_identity_verified                                      NaN
# Prediccion_property_type                                               NaN
# Prediccion_instant_bookable                                      -0.595069
# Prediccion_review_scores_cleanliness                              1.000000
# Prediccion_bathrooms                                                   NaN
# host_response_rate                                                0.353774
# host_is_superhost                                                 0.353774
# host_identity_verified                                                 NaN
# property_type                                                          NaN
# instant_bookable                                                  0.595069
# accommodates                                                      0.353774
# bathrooms                                                              NaN
# price                                                             0.182647
# review_scores_cleanliness                                         1.000000
#
#                                       Prediccion_bathrooms  \
# Prediccion_host_response_rate                          NaN
# Prediccion_host_is_superhost                           NaN
# Prediccion_host_identity_verified                      NaN
# Prediccion_property_type                               NaN
# Prediccion_instant_bookable                            NaN
# Prediccion_review_scores_cleanliness                   NaN
# Prediccion_bathrooms                                   NaN
# host_response_rate                                     NaN
# host_is_superhost                                      NaN
# host_identity_verified                                 NaN
# property_type                                          NaN
# instant_bookable                                       NaN
# accommodates                                           NaN
# bathrooms                                              NaN
# price                                                  NaN
# review_scores_cleanliness                              NaN
#
#                                       host_response_rate  host_is_superhost  \
# Prediccion_host_response_rate                  -1.000000          -1.000000
# Prediccion_host_is_superhost                   -1.000000          -1.000000
# Prediccion_host_identity_verified                    NaN                NaN
# Prediccion_property_type                             NaN                NaN
# Prediccion_instant_bookable                    -0.632456          -0.632456
# Prediccion_review_scores_cleanliness            0.353774           0.353774
# Prediccion_bathrooms                                 NaN                NaN
# host_response_rate                              1.000000           1.000000
# host_is_superhost                               1.000000           1.000000
# host_identity_verified                               NaN                NaN
# property_type                                        NaN                NaN
# instant_bookable                                0.632456           0.632456
# accommodates                                    1.000000           1.000000
# bathrooms                                            NaN                NaN
# price                                          -0.769339          -0.769339
# review_scores_cleanliness                       0.353774           0.353774
#
#                                       host_identity_verified  property_type  \
# Prediccion_host_response_rate                            NaN            NaN
# Prediccion_host_is_superhost                             NaN            NaN
# Prediccion_host_identity_verified                        NaN            NaN
# Prediccion_property_type                                 NaN            NaN
# Prediccion_instant_bookable                              NaN            NaN
# Prediccion_review_scores_cleanliness                     NaN            NaN
# Prediccion_bathrooms                                     NaN            NaN
# host_response_rate                                       NaN            NaN
# host_is_superhost                                        NaN            NaN
# host_identity_verified                                   NaN            NaN
# property_type                                            NaN            NaN
# instant_bookable                                         NaN            NaN
# accommodates                                             NaN            NaN
# bathrooms                                                NaN            NaN
# price                                                    NaN            NaN
# review_scores_cleanliness                                NaN            NaN
#
#                                       instant_bookable  accommodates  \
# Prediccion_host_response_rate                -0.632456     -1.000000
# Prediccion_host_is_superhost                 -0.632456     -1.000000
# Prediccion_host_identity_verified                  NaN           NaN
# Prediccion_property_type                           NaN           NaN
# Prediccion_instant_bookable                  -1.000000     -0.632456
# Prediccion_review_scores_cleanliness          0.595069      0.353774
# Prediccion_bathrooms                               NaN           NaN
# host_response_rate                            0.632456      1.000000
# host_is_superhost                             0.632456      1.000000
# host_identity_verified                             NaN           NaN
# property_type                                      NaN           NaN
# instant_bookable                              1.000000      0.632456
# accommodates                                  0.632456      1.000000
# bathrooms                                          NaN           NaN
# price                                        -0.048320     -0.769339
# review_scores_cleanliness                     0.595069      0.353774
#
#                                       bathrooms     price  \
# Prediccion_host_response_rate               NaN  0.769339
# Prediccion_host_is_superhost                NaN  0.769339
# Prediccion_host_identity_verified           NaN       NaN
# Prediccion_property_type                    NaN       NaN
# Prediccion_instant_bookable                 NaN  0.048320
# Prediccion_review_scores_cleanliness        NaN  0.182647
# Prediccion_bathrooms                        NaN       NaN
# host_response_rate                          NaN -0.769339
# host_is_superhost                           NaN -0.769339
# host_identity_verified                      NaN       NaN
# property_type                               NaN       NaN
# instant_bookable                            NaN -0.048320
# accommodates                                NaN -0.769339
# bathrooms                                   NaN       NaN
# price                                       NaN  1.000000
# review_scores_cleanliness                   NaN  0.182647
#
#                                       review_scores_cleanliness
# Prediccion_host_response_rate                         -0.353774
# Prediccion_host_is_superhost                          -0.353774
# Prediccion_host_identity_verified                           NaN
# Prediccion_property_type                                    NaN
# Prediccion_instant_bookable                           -0.595069
# Prediccion_review_scores_cleanliness                   1.000000
# Prediccion_bathrooms                                        NaN
# host_response_rate                                     0.353774
# host_is_superhost                                      0.353774
# host_identity_verified                                      NaN
# property_type                                               NaN
# instant_bookable                                       0.595069
# accommodates                                           0.353774
# bathrooms                                                   NaN
# price                                                  0.182647
# review_scores_cleanliness                              1.000000

# %%
#Encontramos el valor absoluto de todas las correlaciones entre las variables 
Corr_Factors1= abs(Corr_Factors)
Corr_Factors1
# Out:
#                                       Prediccion_host_response_rate  \
# Prediccion_host_response_rate                              1.000000
# Prediccion_host_is_superhost                               1.000000
# Prediccion_host_identity_verified                               NaN
# Prediccion_property_type                                        NaN
# Prediccion_instant_bookable                                0.632456
# Prediccion_review_scores_cleanliness                       0.353774
# Prediccion_bathrooms                                            NaN
# host_response_rate                                         1.000000
# host_is_superhost                                          1.000000
# host_identity_verified                                          NaN
# property_type                                                   NaN
# instant_bookable                                           0.632456
# accommodates                                               1.000000
# bathrooms                                                       NaN
# price                                                      0.769339
# review_scores_cleanliness                                  0.353774
#
#                                       Prediccion_host_is_superhost  \
# Prediccion_host_response_rate                             1.000000
# Prediccion_host_is_superhost                              1.000000
# Prediccion_host_identity_verified                              NaN
# Prediccion_property_type                                       NaN
# Prediccion_instant_bookable                               0.632456
# Prediccion_review_scores_cleanliness                      0.353774
# Prediccion_bathrooms                                           NaN
# host_response_rate                                        1.000000
# host_is_superhost                                         1.000000
# host_identity_verified                                         NaN
# property_type                                                  NaN
# instant_bookable                                          0.632456
# accommodates                                              1.000000
# bathrooms                                                      NaN
# price                                                     0.769339
# review_scores_cleanliness                                 0.353774
#
#                                       Prediccion_host_identity_verified  \
# Prediccion_host_response_rate                                       NaN
# Prediccion_host_is_superhost                                        NaN
# Prediccion_host_identity_verified                                   NaN
# Prediccion_property_type                                            NaN
# Prediccion_instant_bookable                                         NaN
# Prediccion_review_scores_cleanliness                                NaN
# Prediccion_bathrooms                                                NaN
# host_response_rate                                                  NaN
# host_is_superhost                                                   NaN
# host_identity_verified                                              NaN
# property_type                                                       NaN
# instant_bookable                                                    NaN
# accommodates                                                        NaN
# bathrooms                                                           NaN
# price                                                               NaN
# review_scores_cleanliness                                           NaN
#
#                                       Prediccion_property_type  \
# Prediccion_host_response_rate                              NaN
# Prediccion_host_is_superhost                               NaN
# Prediccion_host_identity_verified                          NaN
# Prediccion_property_type                                   NaN
# Prediccion_instant_bookable                                NaN
# Prediccion_review_scores_cleanliness                       NaN
# Prediccion_bathrooms                                       NaN
# host_response_rate                                         NaN
# host_is_superhost                                          NaN
# host_identity_verified                                     NaN
# property_type                                              NaN
# instant_bookable                                           NaN
# accommodates                                               NaN
# bathrooms                                                  NaN
# price                                                      NaN
# review_scores_cleanliness                                  NaN
#
#                                       Prediccion_instant_bookable  \
# Prediccion_host_response_rate                            0.632456
# Prediccion_host_is_superhost                             0.632456
# Prediccion_host_identity_verified                             NaN
# Prediccion_property_type                                      NaN
# Prediccion_instant_bookable                              1.000000
# Prediccion_review_scores_cleanliness                     0.595069
# Prediccion_bathrooms                                          NaN
# host_response_rate                                       0.632456
# host_is_superhost                                        0.632456
# host_identity_verified                                        NaN
# property_type                                                 NaN
# instant_bookable                                         1.000000
# accommodates                                             0.632456
# bathrooms                                                     NaN
# price                                                    0.048320
# review_scores_cleanliness                                0.595069
#
#                                       Prediccion_review_scores_cleanliness  \
# Prediccion_host_response_rate                                     0.353774
# Prediccion_host_is_superhost                                      0.353774
# Prediccion_host_identity_verified                                      NaN
# Prediccion_property_type                                               NaN
# Prediccion_instant_bookable                                       0.595069
# Prediccion_review_scores_cleanliness                              1.000000
# Prediccion_bathrooms                                                   NaN
# host_response_rate                                                0.353774
# host_is_superhost                                                 0.353774
# host_identity_verified                                                 NaN
# property_type                                                          NaN
# instant_bookable                                                  0.595069
# accommodates                                                      0.353774
# bathrooms                                                              NaN
# price                                                             0.182647
# review_scores_cleanliness                                         1.000000
#
#                                       Prediccion_bathrooms  \
# Prediccion_host_response_rate                          NaN
# Prediccion_host_is_superhost                           NaN
# Prediccion_host_identity_verified                      NaN
# Prediccion_property_type                               NaN
# Prediccion_instant_bookable                            NaN
# Prediccion_review_scores_cleanliness                   NaN
# Prediccion_bathrooms                                   NaN
# host_response_rate                                     NaN
# host_is_superhost                                      NaN
# host_identity_verified                                 NaN
# property_type                                          NaN
# instant_bookable                                       NaN
# accommodates                                           NaN
# bathrooms                                              NaN
# price                                                  NaN
# review_scores_cleanliness                              NaN
#
#                                       host_response_rate  host_is_superhost  \
# Prediccion_host_response_rate                   1.000000           1.000000
# Prediccion_host_is_superhost                    1.000000           1.000000
# Prediccion_host_identity_verified                    NaN                NaN
# Prediccion_property_type                             NaN                NaN
# Prediccion_instant_bookable                     0.632456           0.632456
# Prediccion_review_scores_cleanliness            0.353774           0.353774
# Prediccion_bathrooms                                 NaN                NaN
# host_response_rate                              1.000000           1.000000
# host_is_superhost                               1.000000           1.000000
# host_identity_verified                               NaN                NaN
# property_type                                        NaN                NaN
# instant_bookable                                0.632456           0.632456
# accommodates                                    1.000000           1.000000
# bathrooms                                            NaN                NaN
# price                                           0.769339           0.769339
# review_scores_cleanliness                       0.353774           0.353774
#
#                                       host_identity_verified  property_type  \
# Prediccion_host_response_rate                            NaN            NaN
# Prediccion_host_is_superhost                             NaN            NaN
# Prediccion_host_identity_verified                        NaN            NaN
# Prediccion_property_type                                 NaN            NaN
# Prediccion_instant_bookable                              NaN            NaN
# Prediccion_review_scores_cleanliness                     NaN            NaN
# Prediccion_bathrooms                                     NaN            NaN
# host_response_rate                                       NaN            NaN
# host_is_superhost                                        NaN            NaN
# host_identity_verified                                   NaN            NaN
# property_type                                            NaN            NaN
# instant_bookable                                         NaN            NaN
# accommodates                                             NaN            NaN
# bathrooms                                                NaN            NaN
# price                                                    NaN            NaN
# review_scores_cleanliness                                NaN            NaN
#
#                                       instant_bookable  accommodates  \
# Prediccion_host_response_rate                 0.632456      1.000000
# Prediccion_host_is_superhost                  0.632456      1.000000
# Prediccion_host_identity_verified                  NaN           NaN
# Prediccion_property_type                           NaN           NaN
# Prediccion_instant_bookable                   1.000000      0.632456
# Prediccion_review_scores_cleanliness          0.595069      0.353774
# Prediccion_bathrooms                               NaN           NaN
# host_response_rate                            0.632456      1.000000
# host_is_superhost                             0.632456      1.000000
# host_identity_verified                             NaN           NaN
# property_type                                      NaN           NaN
# instant_bookable                              1.000000      0.632456
# accommodates                                  0.632456      1.000000
# bathrooms                                          NaN           NaN
# price                                         0.048320      0.769339
# review_scores_cleanliness                     0.595069      0.353774
#
#                                       bathrooms     price  \
# Prediccion_host_response_rate               NaN  0.769339
# Prediccion_host_is_superhost                NaN  0.769339
# Prediccion_host_identity_verified           NaN       NaN
# Prediccion_property_type                    NaN       NaN
# Prediccion_instant_bookable                 NaN  0.048320
# Prediccion_review_scores_cleanliness        NaN  0.182647
# Prediccion_bathrooms                        NaN       NaN
# host_response_rate                          NaN  0.769339
# host_is_superhost                           NaN  0.769339
# host_identity_verified                      NaN       NaN
# property_type                               NaN       NaN
# instant_bookable                            NaN  0.048320
# accommodates                                NaN  0.769339
# bathrooms                                   NaN       NaN
# price                                       NaN  1.000000
# review_scores_cleanliness                   NaN  0.182647
#
#                                       review_scores_cleanliness
# Prediccion_host_response_rate                          0.353774
# Prediccion_host_is_superhost                           0.353774
# Prediccion_host_identity_verified                           NaN
# Prediccion_property_type                                    NaN
# Prediccion_instant_bookable                            0.595069
# Prediccion_review_scores_cleanliness                   1.000000
# Prediccion_bathrooms                                        NaN
# host_response_rate                                     0.353774
# host_is_superhost                                      0.353774
# host_identity_verified                                      NaN
# property_type                                               NaN
# instant_bookable                                       0.595069
# accommodates                                           0.353774
# bathrooms                                                   NaN
# price                                                  0.182647
# review_scores_cleanliness                              1.000000

# %%
#Graficamos el mapa de calor de las coeficientes de correlación 
Heart_Nap = sns.heatmap(Corr_Factors1, cmap= 'coolwarm')
Heart_Nap
# Out:
# <Axes: >

# %%
#mapa de calor de las coeficientes de correlación 
plt.figure(figsize=(12,8))
Heart_Nap = sns.heatmap(Corr_Factors1, cmap= 'Oranges', annot=True, fmt=".2f")
Heart_Nap
# Out:
# <Axes: >

# %%
# Obtener R2
r2_1 = model.score(Var_Indep, Var_Dep)
r2_2 = model2.score(Var_Indep2, Var_Dep)
r2_3 = model3.score(Var_Indep3, Var_Dep)
r2_4 = model4.score(Var_Indep4, Var_Dep)
r2_5 = model5.score(Var_Indep5, Var_Dep)
r2_6 = model6.score(Var_Indep6, Var_Dep)
r2_7 = model7.score(Var_Indep7, Var_Dep)
r2_8 = model8.score(Var_Indep8, Var_Dep2)

# Guardar los resultados 
r2_values = {
    "host_response_rate": r2_1,
    "host_is_superhost": r2_2,
    "room_type": r2_3,
    "host_identity_verified": r2_4,
    "property_type": r2_5,
    "instant_bookable": r2_6,
    "review_scores_cleanliness": r2_7,
    "bathrooms": r2_8
}

#Muestra las tres mejores variables
top_3 = sorted(r2_values.items(), key=lambda x: x[1], reverse=True)[:3]
print("Las variables con mayor correlación son:")
for variable, r2 in top_3:
    print(f"{variable}: R² = {r2:.4f}")
# Out:
# Las variables con mayor correlación son:
# host_response_rate: R² = 0.5919
# host_is_superhost: R² = 0.5919
# review_scores_cleanliness: R² = 0.0334
